# %% [markdown]
# # Peak Flow
#
# Run delineations for both the "series" and "parallel" approaches.

# %%
from pathlib import Path
import json
from statistics import mean
import math
from typing import List
from pprint import PrettyPrinter

# from arcpy import FeatureSet, RecordSet, Raster, Describe, CreateUniqueName, EnvManager, SpatialReference
# from arcpy.management import (
#     MakeFeatureLayer, 
#     SelectLayerByAttribute, 
#     GetCount, 
#     MakeTableView, 
#     BuildRasterAttributeTable,
#     Dissolve,
#     AddFields,
#     CreateFeatureclass
# )
# from arcpy.analysis import Buffer
# from arcpy.sa import Watershed, FlowLength, ZonalStatisticsAsTable, SetNull, IsNull
# from arcpy.da import SearchCursor, InsertCursor
# from arcpy.conversion import RasterToPolygon, JSONToFeatures

from dataclasses import dataclass, field, asdict
from marshmallow import Schema, fields, EXCLUDE, pre_load
from marshmallow_dataclass import class_schema

from tqdm.notebook import tqdm
import petl as etl

# import arcgis

# %%
pp = PrettyPrinter(indent=2).pprint

# %%
wd = Path(r"D:\Dropbox (CivicMapper)\Projects\202004-02 Cornell Modeling\3 - Production\tool outputs")
test_results_dir = wd / "c19 tests" / "test_results"

rainfall_rasters_config = Path(r"D:\Dropbox (CivicMapper)\Projects\202004-02 Cornell Modeling\3 - Production\tool outputs\c19 tests\noaa_rainfall\noaa_rainfall_rasters_config_ne.json")

inlets = wd / "c19 tests"  / "c19_snapped_points.shp"
dem = wd / "c19 tests" / "dem_clip_simple.tif"
fd = wd / "c19 tests" / "dem_clip_simple_flowdir.tif"
cn = wd / "c19 tests" / "curveno.tif"
slope = wd / "c19 tests" / "dem_slope.tif"

pour_point_field = "NAACC_ID"
out_catchment_polygons_simplify = False

# %%
test_points_json_path = Path(r'C:\Users\chris\dev\drainage\drainit\tests\points_after_delineation.json')

# %% [markdown]
# ## Models:

# %%
@dataclass
class Rainfall:
    """storm frequency interval with rainfall values and rainfall-dependent 
    analytical results from the calculators
    """

    freq: int = None
    dur: str = None
    value: float = None
        
RainfallSchema = class_schema(Rainfall)

# %%
@dataclass
class Shed:
    """Characteristics of a single point's contributing area
    """
    # unique id field, derived from the outlet point; the value from the
    # "pour_point_field". For NAACC-based culvert modeling, this is the
    # NAACC Naacc_Culvert_Id field
    uid: str = None
    
    # a group id field. non-unique ID field that indicates groups of related
    # outlets. Used primarily for NAACC-based culvert modeling, this is the
    # NAACC Survey_Id field
    group_id: str = None

    # characteristics used for calculating peak flow
    area_sqkm: float = None# <area of inlet's catchment in square km>
    avg_slope_pct: float = None # <average slope of DEM in catchment>
    avg_cn: float = None # <average curve number in the catchment>
    max_fl: float = None # <maximum flow length in the catchment>
    rainfall: List[Rainfall] = None # average rainfall in the catchment, for storm events

    # geometries
    inlet_geom: dict = None
    shed_geom: dict = None
    
    # for recording the location of intermediate geospatial output files
    shed_polygon_filepath: str = None
    shed_raster_filepath: str = None
        
ShedSchema = class_schema(Shed)

# %%
@dataclass
class Point:
    """Basic model for points used as source delineations for peak-flow-calcs;
    minimal attributes required.
    """

    # unique id field, derived from the outlet point; the value from the
    # "pour_point_field". For NAACC-based culvert modeling, this is the
    # NAACC Naacc_Culvert_Id field
    uid: str

    lat: float = None
    lng: float = None
    spatial_ref_code: int = None

    # a group id field. non-unique ID field that indicates groups of related
    # outlets. Used primarily for NAACC-based culvert modeling, this is the
    # NAACC Survey_Id field
    group_id: str = None

    # optionally extend with NAACC & capacity attributes
    # naacc: NaaccCulvert = None
    # capacity: Capacity = None
    naacc: dict = None
    capacity: dict = None

    # optionally extend with the Shed and its characteristics
    shed: Shed = None

    # rainfall frequency-based analytical results for the point
    analytics: List[Rainfall] = field(default_factory=list)

    # flags, errors, and notes
    include: bool = True
    validation_errors: dict = field(default_factory=dict)
    notes: list = field(default_factory=list)

    # place to store the raw input
    raw: dict = None

# %% [markdown]
# ## Read the Points from our test `JSON`

# %%
PointSchema = class_schema(Point)

# %%
with open(test_points_json_path) as fp:
    test_points = json.load(fp)
test_points
# Out:
# {'points': [{'shed': {'area_sqkm': 3198.260236505569,
#     'avg_slope_pct': 16.102196872234344,
#     'rainfall': [{'freq': 1, 'value': 59.74079999999999, 'dur': '24hr'},
#      {'freq': 2, 'value': 74.1172, 'dur': '24hr'},
#      {'freq': 5, 'value': 97.6122, 'dur': '24hr'},
#      {'freq': 10, 'value': 117.1194, 'dur': '24hr'},
#      {'freq': 25, 'value': 143.9672, 'dur': '24hr'},
#      {'freq': 50, 'value': 163.80459999999997, 'dur': '24hr'},
#      {'freq': 100, 'value': 185.3438, 'dur': '24hr'},
#      {'freq': 200, 'value': 211.63279999999997, 'dur': '24hr'},
#      {'freq': 500, 'value': 251.94259999999997, 'dur': '24hr'},
#      {'freq': 1000, 'value': 286.61359999999996, 'dur': '24hr'}],
#     'shed_raster_filepath': 'in_memory/catchment_70978.tif',
#     'avg_cn': 77.75,
#     'max_fl': 88.260292053223,
#     'uid': '70978',
#     'shed_geom': None,
#     'shed_polygon_filepath': 'in_memory\\basin70978_dissolved',
#     'inlet_geom': None,
#     'group_id': None},
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 618918.2765349224,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '70978',
#    'naacc': None,
#    'lat': 4690423.416399388,
#    'raw': {'OBJECTID': 1,
#     'pointid': 1,
#     'grid_code': 70978,
#     'Survey_ID': 73607,
#     'NAACC_ID': 70978,
#     'Lat': 42.35717,
#     'Long': -73.556041,
#     'Rd_Name': 'Raup Road',
#     'Culv_Mat': 'Metal',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 4.9,
#     'In_B': 4.8,
#     'HW': 2,
#     'Slope': 2.8,
#     'Length': 26,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 5.2,
#     'Out_B': 5.4,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '96C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 618918.2765349224, 'y': 4690423.416399388}},
#    'group_id': None},
#   {'shed': {'area_sqkm': 1599.1361166362162,
#     'avg_slope_pct': 8.87437504529953,
#     'rainfall': [{'freq': 1, 'value': 56.6928, 'dur': '24hr'},
#      {'freq': 2, 'value': 69.85, 'dur': '24hr'},
#      {'freq': 5, 'value': 91.3384, 'dur': '24hr'},
#      {'freq': 10, 'value': 109.1692, 'dur': '24hr'},
#      {'freq': 25, 'value': 133.7056, 'dur': '24hr'},
#      {'freq': 50, 'value': 151.892, 'dur': '24hr'},
#      {'freq': 100, 'value': 171.55159999999998, 'dur': '24hr'},
#      {'freq': 200, 'value': 195.199, 'dur': '24hr'},
#      {'freq': 500, 'value': 231.013, 'dur': '24hr'},
#      {'freq': 1000, 'value': 261.59459999999996, 'dur': '24hr'}],
#     'shed_raster_filepath': 'in_memory/catchment_71056.tif',
#     'avg_cn': 74.0,
#     'max_fl': 48.271156311035,
#     'uid': '71056',
#     'shed_geom': None,
#     'shed_polygon_filepath': 'in_memory\\basin71056_dissolved',
#     'inlet_geom': None,
#     'group_id': None},
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 610968.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71056',
#    'naacc': None,
#    'lat': 4690193.416399388,
#    'raw': {'OBJECTID': 2,
#     'pointid': 2,
#     'grid_code': 71056,
#     'Survey_ID': 73685,
#     'NAACC_ID': 71056,
#     'Lat': 42.356053,
#     'Long': -73.652552,
#     'Rd_Name': 'Mile Hill Road',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Mitered to Slope',
#     'In_Shape': 'Round',
#     'In_A': 1.5,
#     'In_B': 1.3,
#     'HW': 5,
#     'Slope': -1,
#     'Length': 42,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 1.5,
#     'Out_B': 1.5,
#     'Crossing_T': 'Culvert',
#     'Comments': 'headwall on outlet side. large pond downstream',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '121C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 610968.2765349215, 'y': 4690193.416399388}},
#    'group_id': None},
#   {'shed': {'area_sqkm': 960278.1968657345,
#     'avg_slope_pct': 12.437299312749175,
#     'rainfall': [{'freq': 1, 'value': 59.829784596169866, 'dur': '24hr'},
#      {'freq': 2, 'value': 74.23308617818483, 'dur': '24hr'},
#      {'freq': 5, 'value': 97.77590416319732, 'dur': '24hr'},
#      {'freq': 10, 'value': 117.31586402997502, 'dur': '24hr'},
#      {'freq': 25, 'value': 144.20422789342214, 'dur': '24hr'},
#      {'freq': 50, 'value': 164.06771523730225, 'dur': '24hr'},
#      {'freq': 100, 'value': 185.65268176519564, 'dur': '24hr'},
#      {'freq': 200, 'value': 212.02942914238133, 'dur': '24hr'},
#      {'freq': 500, 'value': 252.50813597002494, 'dur': '24hr'},
#      {'freq': 1000, 'value': 287.33972064945874, 'dur': '24hr'}],
#     'shed_raster_filepath': 'in_memory/catchment_70979.tif',
#     'avg_cn': 76.34970857618652,
#     'max_fl': 2084.5324707031,
#     'uid': '70979',
#     'shed_geom': None,
#     'shed_polygon_filepath': 'in_memory\\basin70979_dissolved',
#     'inlet_geom': None,
#     'group_id': None},
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 618868.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '70979',
#    'naacc': None,
#    'lat': 4690163.416399388,
#    'raw': {'OBJECTID': 3,
#     'pointid': 3,
#     'grid_code': 70979,
#     'Survey_ID': 73608,
#     'NAACC_ID': 70979,
#     'Lat': 42.354772,
#     'Long': -73.556639,
#     'Rd_Name': 'Red Rock Road',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Wingwall and Headwall',
#     'In_Shape': 'Box',
#     'In_A': 6,
#     'In_B': 5.1,
#     'HW': 7,
#     'Slope': 6.8,
#     'Length': 35,
#     'Out_Shape': 'Box Culvert',
#     'Out_A': 5.9,
#     'Out_B': 5,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '97C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 618868.2765349215, 'y': 4690163.416399388}},
#    'group_id': None},
#   {'shed': {'area_sqkm': 799.5680583460403,
#     'avg_slope_pct': 10.026969909667969,
#     'rainfall': [{'freq': 1, 'value': 60.0456, 'dur': '24hr'},
#      {'freq': 2, 'value': 74.549, 'dur': '24hr'},
#      {'freq': 5, 'value': 98.2726, 'dur': '24hr'},
#      {'freq': 10, 'value': 117.95759999999999, 'dur': '24hr'},
#      {'freq': 25, 'value': 145.034, 'dur': '24hr'},
#      {'freq': 50, 'value': 165.04919999999998, 'dur': '24hr'},
#      {'freq': 100, 'value': 186.7916, 'dur': '24hr'},
#      {'freq': 200, 'value': 213.30919999999998, 'dur': '24hr'},
#      {'freq': 500, 'value': 253.89839999999998, 'dur': '24hr'},
#      {'freq': 1000, 'value': 288.798, 'dur': '24hr'}],
#     'shed_raster_filepath': 'in_memory/catchment_73324.tif',
#     'avg_cn': 79.0,
#     'max_fl': 28.27659034729,
#     'uid': '73324',
#     'shed_geom': None,
#     'shed_polygon_filepath': 'in_memory\\basin73324_dissolved',
#     'inlet_geom': None,
#     'group_id': None},
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 618848.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '73324',
#    'naacc': None,
#    'lat': 4690093.416399386,
#    'raw': {'OBJECTID': 4,
#     'pointid': 4,
#     'grid_code': 73324,
#     'Survey_ID': 76071,
#     'NAACC_ID': 73324,
#     'Lat': 42.354158,
#     'Long': -73.556776,
#     'Rd_Name': 'Old road',
#     'Culv_Mat': 'Combination',
#     'In_Type': 'Wingwall',
#     'In_Shape': 'Box',
#     'In_A': 19.9,
#     'In_B': 7.1,
#     'HW': 0,
#     'Slope': -1,
#     'Length': 20.4,
#     'Out_Shape': 'Box/Bridge with Abutments',
#     'Out_A': 20,
#     'Out_B': 7.2,
#     'Crossing_T': 'Bridge',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '220C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 618848.2765349206, 'y': 4690093.416399386}},
#    'group_id': None},
#   {'shed': {'area_sqkm': 229475.304935253,
#     'avg_slope_pct': 4.215719690695664,
#     'rainfall': [{'freq': 1, 'value': 56.67912648083623, 'dur': '24hr'},
#      {'freq': 2, 'value': 69.89079930313588, 'dur': '24hr'},
#      {'freq': 5, 'value': 91.46438222996515, 'dur': '24hr'},
#      {'freq': 10, 'value': 109.35403588850173, 'dur': '24hr'},
#      {'freq': 25, 'value': 133.97999965156797, 'dur': '24hr'},
#      {'freq': 50, 'value': 152.24901602787457, 'dur': '24hr'},
#      {'freq': 100, 'value': 171.9700362369338, 'dur': '24hr'},
#      {'freq': 200, 'value': 195.73032020905922, 'dur': '24hr'},
#      {'freq': 500, 'value': 231.7626982578397, 'dur': '24hr'},
#      {'freq': 1000, 'value': 262.51408885017423, 'dur': '24hr'}],
#     'shed_raster_filepath': 'in_memory/catchment_71049.tif',
#     'avg_cn': 73.64634146341463,
#     'max_fl': 1077.1088867188,
#     'uid': '71049',
#     'shed_geom': None,
#     'shed_polygon_filepath': 'in_memory\\basin71049_dissolved',
#     'inlet_geom': None,
#     'group_id': None},
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 612348.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71049',
#    'naacc': None,
#    'lat': 4690083.416399386,
#    'raw': {'OBJECTID': 5,
#     'pointid': 5,
#     'grid_code': 71049,
#     'Survey_ID': 73678,
#     'NAACC_ID': 71049,
#     'Lat': 42.354929,
#     'Long': -73.635924,
#     'Rd_Name': 'Church Sreet',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 3,
#     'In_B': 3,
#     'HW': 1.5,
#     'Slope': 3,
#     'Length': 40,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 3,
#     'Out_B': 3,
#     'Crossing_T': 'Culvert',
#     'Comments': 'buried upstream under field. fish in scour pool',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '115C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 612348.2765349206, 'y': 4690083.416399386}},
#    'group_id': None},
#   {'shed': {'area_sqkm': 399.7840291730201,
#     'avg_slope_pct': 16.088239669799805,
#     'rainfall': [{'freq': 1, 'value': 57.962799999999994, 'dur': '24hr'},
#      {'freq': 2, 'value': 71.72959999999999, 'dur': '24hr'},
#      {'freq': 5, 'value': 94.234, 'dur': '24hr'},
#      {'freq': 10, 'value': 112.903, 'dur': '24hr'},
#      {'freq': 25, 'value': 138.6078, 'dur': '24hr'},
#      {'freq': 50, 'value': 157.65779999999998, 'dur': '24hr'},
#      {'freq': 100, 'value': 178.25719999999998, 'dur': '24hr'},
#      {'freq': 200, 'value': 203.17459999999997, 'dur': '24hr'},
#      {'freq': 500, 'value': 241.0968, 'dur': '24hr'},
#      {'freq': 1000, 'value': 273.5326, 'dur': '24hr'}],
#     'shed_raster_filepath': 'in_memory/catchment_70962.tif',
#     'avg_cn': 36.0,
#     'max_fl': 0.0,
#     'uid': '70962',
#     'shed_geom': None,
#     'shed_polygon_filepath': 'in_memory\\basin70962_dissolved',
#     'inlet_geom': None,
#     'group_id': None},
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 615548.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '70962',
#    'naacc': None,
#    'lat': 4689973.416399388,
#    'raw': {'OBJECTID': 6,
#     'pointid': 6,
#     'grid_code': 70962,
#     'Survey_ID': 73590,
#     'NAACC_ID': 70962,
#     'Lat': 42.353513,
#     'Long': -73.59691,
#     'Rd_Name': 'Coleman Street',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Wingwall and Headwall',
#     'In_Shape': 'Box',
#     'In_A': 5,
#     'In_B': 5,
#     'HW': 5.5,
#     'Slope': 1.3,
#     'Length': 65,
#     'Out_Shape': 'Box Culvert',
#     'Out_A': 5,
#     'Out_B': 5,
#     'Crossing_T': 'Culvert',
#     'Comments': 'considerable erosion upstream and downstream. concrete slabs laying on banks of upstream culvert visible in upstream photo',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '82C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 615548.2765349215, 'y': 4689973.416399388}},
#    'group_id': None},
#   {'shed': {'area_sqkm': 799.562059948987,
#     'avg_slope_pct': 1.820680022239685,
#     'rainfall': [{'freq': 1, 'value': 57.962799999999994, 'dur': '24hr'},
#      {'freq': 2, 'value': 71.72959999999999, 'dur': '24hr'},
#      {'freq': 5, 'value': 94.234, 'dur': '24hr'},
#      {'freq': 10, 'value': 112.903, 'dur': '24hr'},
#      {'freq': 25, 'value': 138.6078, 'dur': '24hr'},
#      {'freq': 50, 'value': 157.65779999999998, 'dur': '24hr'},
#      {'freq': 100, 'value': 178.25719999999998, 'dur': '24hr'},
#      {'freq': 200, 'value': 203.17459999999997, 'dur': '24hr'},
#      {'freq': 500, 'value': 241.0968, 'dur': '24hr'},
#      {'freq': 1000, 'value': 273.5326, 'dur': '24hr'}],
#     'shed_raster_filepath': 'in_memory/catchment_70934.tif',
#     'avg_cn': 41.0,
#     'max_fl': 19.994567871094,
#     'uid': '70934',
#     'shed_geom': None,
#     'shed_polygon_filepath': 'in_memory\\basin70934_dissolved',
#     'inlet_geom': None,
#     'group_id': None},
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 615268.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '70934',
#    'naacc': None,
#    'lat': 4689953.416399388,
#    'raw': {'OBJECTID': 7,
#     'pointid': 7,
#     'grid_code': 70934,
#     'Survey_ID': 73567,
#     'NAACC_ID': 70934,
#     'Lat': 42.353382,
#     'Long': -73.600233,
#     'Rd_Name': 'Payn Road',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Wingwall and Headwall',
#     'In_Shape': 'Box',
#     'In_A': 8.5,
#     'In_B': 1.7,
#     'HW': 2,
#     'Slope': 8.1,
#     'Length': 160,
#     'Out_Shape': 'Unknown',
#     'Out_A': -1,
#     'Out_B': -1,
#     'Crossing_T': 'Partially Inaccessible',
#     'Comments': 'looks buried under yard on outlet side. cant see far through inlet because curves to the left. possibly outlets into yard of house number 30. inlet is across the street from houses 26 and 28. Neighbor says house number 30 owner is 78 yrs old and refuses',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '67C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 615268.2765349206, 'y': 4689953.416399388}},
#    'group_id': None},
#   {'shed': {'area_sqkm': 41977.19309716403,
#     'avg_slope_pct': 8.181410719667163,
#     'rainfall': [{'freq': 1, 'value': 57.98118476190476, 'dur': '24hr'},
#      {'freq': 2, 'value': 71.7547580952381, 'dur': '24hr'},
#      {'freq': 5, 'value': 94.2698019047619, 'dur': '24hr'},
#      {'freq': 10, 'value': 112.94654285714283, 'dur': '24hr'},
#      {'freq': 25, 'value': 138.66295428571428, 'dur': '24hr'},
#      {'freq': 50, 'value': 157.72069523809523, 'dur': '24hr'},
#      {'freq': 100, 'value': 178.32977142857143, 'dur': '24hr'},
#      {'freq': 200, 'value': 203.25975047619048, 'dur': '24hr'},
#      {'freq': 500, 'value': 241.2032380952381, 'dur': '24hr'},
#      {'freq': 1000, 'value': 273.6583904761905, 'dur': '24hr'}],
#     'shed_raster_filepath': 'in_memory/catchment_70964.tif',
#     'avg_cn': 41.923809523809524,
#     'max_fl': 562.68981933594,
#     'uid': '70964',
#     'shed_geom': None,
#     'shed_polygon_filepath': 'in_memory\\basin70964_dissolved',
#     'inlet_geom': None,
#     'group_id': None},
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 615198.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '70964',
#    'naacc': None,
#    'lat': 4689873.416399386,
#    'raw': {'OBJECTID': 8,
#     'pointid': 8,
#     'grid_code': 70964,
#     'Survey_ID': 73592,
#     'NAACC_ID': 70964,
#     'Lat': 42.352664,
#     'Long': -73.601273,
#     'Rd_Name': 'Elm Street',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Wingwall and Headwall',
#     'In_Shape': 'Box',
#     'In_A': 8,
#     'In_B': 3.2,
#     'HW': 2.2,
#     'Slope': 1.9,
#     'Length': 40,
#     'Out_Shape': 'Box Culvert',
#     'Out_A': 8,
#     'Out_B': 5,
#     'Crossing_T': 'Culvert',
#     'Comments': 'small fish and frogs in stream. neighbor says blue heron uses stream. drain grate in between structure and Payn St floods road, sidewalk and yard of house 5. Flooding happens when structure on Payne st floods',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '84C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 615198.2765349215, 'y': 4689873.416399386}},
#    'group_id': None},
#   {'shed': {'area_sqkm': 34781.104565461676,
#     'avg_slope_pct': 1.5085030776159516,
#     'rainfall': [{'freq': 1, 'value': 57.658, 'dur': '24hr'},
#      {'freq': 2, 'value': 71.29780000000001, 'dur': '24hr'},
#      {'freq': 5, 'value': 93.599, 'dur': '24hr'},
#      {'freq': 10, 'value': 112.141, 'dur': '24hr'},
#      {'freq': 25, 'value': 137.61719999999997, 'dur': '24hr'},
#      {'freq': 50, 'value': 156.4894, 'dur': '24hr'},
#      {'freq': 100, 'value': 176.911, 'dur': '24hr'},
#      {'freq': 200, 'value': 201.5744, 'dur': '24hr'},
#      {'freq': 500, 'value': 239.0648, 'dur': '24hr'},
#      {'freq': 1000, 'value': 271.1196, 'dur': '24hr'}],
#     'shed_raster_filepath': 'in_memory/catchment_72494.tif',
#     'avg_cn': 58.35632183908046,
#     'max_fl': 281.34494018555,
#     'uid': '72494',
#     'shed_geom': None,
#     'shed_polygon_filepath': 'in_memory\\basin72494_dissolved',
#     'inlet_geom': None,
#     'group_id': None},
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 614758.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '72494',
#    'naacc': None,
#    'lat': 4689843.416399386,
#    'raw': {'OBJECTID': 9,
#     'pointid': 9,
#     'grid_code': 72494,
#     'Survey_ID': 75154,
#     'NAACC_ID': 72494,
#     'Lat': 42.352439,
#     'Long': -73.606888,
#     'Rd_Name': 'Hudson Plaza',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 2,
#     'In_B': 1.7,
#     'HW': 1,
#     'Slope': 8.1,
#     'Length': 100,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 2,
#     'Out_B': 1.5,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '197C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 614758.2765349215, 'y': 4689843.416399386}},
#    'group_id': None},
#   {'shed': {'area_sqkm': 321425.3297240745,
#     'avg_slope_pct': 12.584468117400782,
#     'rainfall': [{'freq': 1, 'value': 61.21447388059701, 'dur': '24hr'},
#      {'freq': 2, 'value': 76.19459776119402, 'dur': '24hr'},
#      {'freq': 5, 'value': 100.67119402985074, 'dur': '24hr'},
#      {'freq': 10, 'value': 120.98323283582089, 'dur': '24hr'},
#      {'freq': 25, 'value': 148.92579179104476, 'dur': '24hr'},
#      {'freq': 50, 'value': 169.5551410447761, 'dur': '24hr'},
#      {'freq': 100, 'value': 192.02513731343282, 'dur': '24hr'},
#      {'freq': 200, 'value': 219.61342313432834, 'dur': '24hr'},
#      {'freq': 500, 'value': 262.13198059701494, 'dur': '24hr'},
#      {'freq': 1000, 'value': 298.79934477611937, 'dur': '24hr'}],
#     'shed_raster_filepath': 'in_memory/catchment_70995.tif',
#     'avg_cn': 78.13930348258707,
#     'max_fl': 1317.0439453125,
#     'uid': '70995',
#     'shed_geom': None,
#     'shed_polygon_filepath': 'in_memory\\basin70995_dissolved',
#     'inlet_geom': None,
#     'group_id': None},
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 620528.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '70995',
#    'naacc': None,
#    'lat': 4689743.416399388,
#    'raw': {'OBJECTID': 10,
#     'pointid': 10,
#     'grid_code': 70995,
#     'Survey_ID': 73624,
#     'NAACC_ID': 70995,
#     'Lat': 42.350532,
#     'Long': -73.53654,
#     'Rd_Name': 'Ten Broek Road',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 4,
#     'In_B': 3.8,
#     'HW': 2.8,
#     'Slope': 9.1,
#     'Length': 40,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 3.9,
#     'Out_B': 3.8,
#     'Crossing_T': 'Culvert',
#     'Comments': 'driveway culvert upstream. lots of erosion downstream',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '107C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 620528.2765349206, 'y': 4689743.416399388}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 614888.2765349224,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '72495',
#    'naacc': None,
#    'lat': 4689723.416399388,
#    'raw': {'OBJECTID': 11,
#     'pointid': 11,
#     'grid_code': 72495,
#     'Survey_ID': 75155,
#     'NAACC_ID': 72495,
#     'Lat': 42.351419,
#     'Long': -73.605115,
#     'Rd_Name': 'Hudson Plaza',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 2,
#     'In_B': 2,
#     'HW': 1.2,
#     'Slope': 2.4,
#     'Length': 145,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 2,
#     'Out_B': 2,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '198C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 614888.2765349224, 'y': 4689723.416399388}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 614998.2765349224,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '72496',
#    'naacc': None,
#    'lat': 4689633.416399386,
#    'raw': {'OBJECTID': 12,
#     'pointid': 12,
#     'grid_code': 72496,
#     'Survey_ID': 75156,
#     'NAACC_ID': 72496,
#     'Lat': 42.350545,
#     'Long': -73.603894,
#     'Rd_Name': 'Dardess road',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 2.5,
#     'In_B': 2.5,
#     'HW': 2,
#     'Slope': 0.5,
#     'Length': 100,
#     'Out_Shape': 'Box Culvert',
#     'Out_A': 8,
#     'Out_B': 2.5,
#     'Crossing_T': 'Culvert',
#     'Comments': 'ID:c810800',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '199C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 614998.2765349224, 'y': 4689633.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 617188.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '73320',
#    'naacc': None,
#    'lat': 4689473.416399388,
#    'raw': {'OBJECTID': 13,
#     'pointid': 13,
#     'grid_code': 73320,
#     'Survey_ID': 76070,
#     'NAACC_ID': 73320,
#     'Lat': 42.348702,
#     'Long': -73.577014,
#     'Rd_Name': 'TSP',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Wingwall and Headwall',
#     'In_Shape': 'Box',
#     'In_A': 12,
#     'In_B': 14.2,
#     'HW': 12,
#     'Slope': 0.3,
#     'Length': 218,
#     'Out_Shape': 'Box Culvert',
#     'Out_A': 12,
#     'Out_B': 14,
#     'Crossing_T': 'Multiple Culvert',
#     'Comments': 'Debris jam clogging three cells. Only one functioning. Small Trib joins Punsit ~100 ft upstream of inlet. Large bar deposit at inlet',
#     'Flags': 4,
#     'Modeling_n': ' ',
#     'BarrierID': '216C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 617188.2765349215, 'y': 4689473.416399388}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 614958.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '72500',
#    'naacc': None,
#    'lat': 4689443.416399386,
#    'raw': {'OBJECTID': 14,
#     'pointid': 14,
#     'grid_code': 72500,
#     'Survey_ID': 75159,
#     'NAACC_ID': 72500,
#     'Lat': 42.348877,
#     'Long': -73.604209,
#     'Rd_Name': 'Payn Avenue',
#     'Culv_Mat': 'Metal',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 1.5,
#     'In_B': 1.2,
#     'HW': 1.5,
#     'Slope': 0.6,
#     'Length': 90,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 3,
#     'Out_B': 2.4,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '203C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 614958.2765349215, 'y': 4689443.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 617808.2765349196,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '70150',
#    'naacc': None,
#    'lat': 4689433.416399386,
#    'raw': {'OBJECTID': 15,
#     'pointid': 15,
#     'grid_code': 70150,
#     'Survey_ID': 72735,
#     'NAACC_ID': 70150,
#     'Lat': 42.348382,
#     'Long': -73.569626,
#     'Rd_Name': 'Route 203',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Wingwall and Headwall',
#     'In_Shape': 'Box',
#     'In_A': 18,
#     'In_B': 8.5,
#     'HW': 2.5,
#     'Slope': -1,
#     'Length': 25,
#     'Out_Shape': 'Box/Bridge with Abutments',
#     'Out_A': 18,
#     'Out_B': 8,
#     'Crossing_T': 'Culvert',
#     'Comments': 'code 840941. inaccessible for slope and inlet and outlet pictures. steep drop off hidden by vines and other vegetation',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '54C19',
#     'BarrierID_': -118.336503466,
#     'BarrierID1': 9751785204900000,
#     'geometry': {'x': 617808.2765349196, 'y': 4689433.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 623138.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '70994',
#    'naacc': None,
#    'lat': 4689423.416399386,
#    'raw': {'OBJECTID': 16,
#     'pointid': 16,
#     'grid_code': 70994,
#     'Survey_ID': 73623,
#     'NAACC_ID': 70994,
#     'Lat': 42.347303,
#     'Long': -73.504827,
#     'Rd_Name': 'Stonewall Road',
#     'Culv_Mat': 'Metal',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 7.2,
#     'In_B': 7.3,
#     'HW': 1,
#     'Slope': 6.1,
#     'Length': 52,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 7.3,
#     'Out_B': 7.1,
#     'Crossing_T': 'Culvert',
#     'Comments': 'Fish next to outlet. waterfall cascade over rocks upstream',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '106C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 623138.2765349215, 'y': 4689423.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 608798.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71652',
#    'naacc': None,
#    'lat': 4689383.416399386,
#    'raw': {'OBJECTID': 17,
#     'pointid': 17,
#     'grid_code': 71652,
#     'Survey_ID': 74261,
#     'NAACC_ID': 71652,
#     'Lat': 42.349241,
#     'Long': -73.678983,
#     'Rd_Name': 'Letter S Road',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 1.5,
#     'In_B': 1.5,
#     'HW': 1.5,
#     'Slope': 1.2,
#     'Length': 40,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 1.5,
#     'Out_B': 1.5,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '146C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 608798.2765349206, 'y': 4689383.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 614908.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '72502',
#    'naacc': None,
#    'lat': 4689293.416399388,
#    'raw': {'OBJECTID': 18,
#     'pointid': 18,
#     'grid_code': 72502,
#     'Survey_ID': 75161,
#     'NAACC_ID': 72502,
#     'Lat': 42.347581,
#     'Long': -73.604898,
#     'Rd_Name': 'Price Chopper Drive',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Headwall',
#     'In_Shape': 'Box',
#     'In_A': 12,
#     'In_B': 4.5,
#     'HW': 3.5,
#     'Slope': 0.3,
#     'Length': 39,
#     'Out_Shape': 'Box Culvert',
#     'Out_A': 12,
#     'Out_B': 4.5,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '205C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 614908.2765349206, 'y': 4689293.416399388}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 623308.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71003',
#    'naacc': None,
#    'lat': 4689293.416399388,
#    'raw': {'OBJECTID': 19,
#     'pointid': 19,
#     'grid_code': 71003,
#     'Survey_ID': 73632,
#     'NAACC_ID': 71003,
#     'Lat': 42.346303,
#     'Long': -73.502917,
#     'Rd_Name': 'Old Macedonia Road',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 4,
#     'In_B': 4,
#     'HW': 1,
#     'Slope': 5.6,
#     'Length': 40,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 4,
#     'Out_B': 4,
#     'Crossing_T': 'Culvert',
#     'Comments': 'second round pipe with fence for overflow off to the side. orange colored water',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '113C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 623308.2765349206, 'y': 4689293.416399388}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 621198.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '70996',
#    'naacc': None,
#    'lat': 4689183.416399386,
#    'raw': {'OBJECTID': 20,
#     'pointid': 20,
#     'grid_code': 70996,
#     'Survey_ID': 73625,
#     'NAACC_ID': 70996,
#     'Lat': 42.345451,
#     'Long': -73.528468,
#     'Rd_Name': 'Ten Broek Road',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 2.9,
#     'In_B': 3,
#     'HW': 1.2,
#     'Slope': 0.5,
#     'Length': 38,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 3,
#     'Out_B': 3,
#     'Crossing_T': 'Culvert',
#     'Comments': 'larger fish darted out from underneath concrete slab',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '108C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 621198.2765349206, 'y': 4689183.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 623848.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '70973',
#    'naacc': None,
#    'lat': 4689163.416399386,
#    'raw': {'OBJECTID': 21,
#     'pointid': 21,
#     'grid_code': 70973,
#     'Survey_ID': 73600,
#     'NAACC_ID': 70973,
#     'Lat': 42.34483,
#     'Long': -73.496334,
#     'Rd_Name': 'Old Macedonia Road',
#     'Culv_Mat': 'Metal',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 5.8,
#     'In_B': 5.8,
#     'HW': 2,
#     'Slope': 6.5,
#     'Length': 30,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 6,
#     'Out_B': 5.9,
#     'Crossing_T': 'Culvert',
#     'Comments': 'bedrock at outlet. build up of logs and debris downstream. no evidence of beavers. road fill is mostly boulders and some gravel for road',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '92C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 623848.2765349206, 'y': 4689163.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 614848.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '70963',
#    'naacc': None,
#    'lat': 4689143.416399386,
#    'raw': {'OBJECTID': 22,
#     'pointid': 22,
#     'grid_code': 70963,
#     'Survey_ID': 73591,
#     'NAACC_ID': 70963,
#     'Lat': 42.346259,
#     'Long': -73.605656,
#     'Rd_Name': 'Taconic Place',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 5,
#     'In_B': 5,
#     'HW': 5,
#     'Slope': 1.3,
#     'Length': 40,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 5,
#     'Out_B': 5,
#     'Crossing_T': 'Culvert',
#     'Comments': 'heron using scour pool shown in other picture 2',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '83C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 614848.2765349215, 'y': 4689143.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 622278.2765349196,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71001',
#    'naacc': None,
#    'lat': 4689143.416399386,
#    'raw': {'OBJECTID': 23,
#     'pointid': 23,
#     'grid_code': 71001,
#     'Survey_ID': 73631,
#     'NAACC_ID': 71001,
#     'Lat': 42.34498,
#     'Long': -73.515309,
#     'Rd_Name': 'Braley-Gleason Rd',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 1.5,
#     'In_B': 1.5,
#     'HW': 3.3,
#     'Slope': 8.9,
#     'Length': 35,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 1.5,
#     'Out_B': 1.5,
#     'Crossing_T': 'Culvert',
#     'Comments': 'partially inaccessible but measurements estimated',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '112C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 622278.2765349196, 'y': 4689143.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 616558.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '70983',
#    'naacc': None,
#    'lat': 4689083.416399388,
#    'raw': {'OBJECTID': 24,
#     'pointid': 24,
#     'grid_code': 70983,
#     'Survey_ID': 73612,
#     'NAACC_ID': 70983,
#     'Lat': 42.345127,
#     'Long': -73.584883,
#     'Rd_Name': 'Route 9',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 3,
#     'In_B': 2.9,
#     'HW': 2.5,
#     'Slope': 8.4,
#     'Length': 30,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 3,
#     'Out_B': 2.9,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '100C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 616558.2765349215, 'y': 4689083.416399388}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 625558.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '70992',
#    'naacc': None,
#    'lat': 4688953.416399386,
#    'raw': {'OBJECTID': 25,
#     'pointid': 25,
#     'grid_code': 70992,
#     'Survey_ID': 73622,
#     'NAACC_ID': 70992,
#     'Lat': 42.34256,
#     'Long': -73.47568,
#     'Rd_Name': 'Old Macedonia Road',
#     'Culv_Mat': 'Metal',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 1.5,
#     'In_B': 1.5,
#     'HW': 2.5,
#     'Slope': 4.7,
#     'Length': 30,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 1.5,
#     'Out_B': 1.5,
#     'Crossing_T': 'Multiple Culvert',
#     'Comments': 'perched high above stream bed. water flows down cascade of boulders',
#     'Flags': 2,
#     'Modeling_n': ' ',
#     'BarrierID': '104C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 625558.2765349206, 'y': 4688953.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 621548.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '70997',
#    'naacc': None,
#    'lat': 4688793.416399388,
#    'raw': {'OBJECTID': 26,
#     'pointid': 26,
#     'grid_code': 70997,
#     'Survey_ID': 73626,
#     'NAACC_ID': 70997,
#     'Lat': 42.341843,
#     'Long': -73.524254,
#     'Rd_Name': 'Ten Broek Road',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 4,
#     'In_B': 4,
#     'HW': 2.5,
#     'Slope': -1,
#     'Length': 25,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 4,
#     'Out_B': 4,
#     'Crossing_T': 'Multiple Culvert',
#     'Comments': 'inlets inaccessible but measurements estimated by looking through outlet. could not get pictures or slope',
#     'Flags': 2,
#     'Modeling_n': ' ',
#     'BarrierID': '109C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 621548.2765349215, 'y': 4688793.416399388}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 606698.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71431',
#    'naacc': None,
#    'lat': 4688783.416399386,
#    'raw': {'OBJECTID': 27,
#     'pointid': 27,
#     'grid_code': 71431,
#     'Survey_ID': 74033,
#     'NAACC_ID': 71431,
#     'Lat': 42.344006,
#     'Long': -73.704782,
#     'Rd_Name': 'Route 9H',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Headwall',
#     'In_Shape': 'Round',
#     'In_A': 3,
#     'In_B': 3,
#     'HW': 3.5,
#     'Slope': 0.3,
#     'Length': 50,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 3,
#     'Out_B': 3,
#     'Crossing_T': 'Culvert',
#     'Comments': 'lots of fish swimming in and around structure',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '125C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 606698.2765349215, 'y': 4688783.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 609218.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71649',
#    'naacc': None,
#    'lat': 4688693.416399386,
#    'raw': {'OBJECTID': 28,
#     'pointid': 28,
#     'grid_code': 71649,
#     'Survey_ID': 74258,
#     'NAACC_ID': 71649,
#     'Lat': 42.343016,
#     'Long': -73.67407,
#     'Rd_Name': 'Letter S Road',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 3,
#     'In_B': 3,
#     'HW': 1,
#     'Slope': 1,
#     'Length': 40,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 3,
#     'Out_B': 3,
#     'Crossing_T': 'Multiple Culvert',
#     'Comments': ' ',
#     'Flags': 2,
#     'Modeling_n': ' ',
#     'BarrierID': '143C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 609218.2765349206, 'y': 4688693.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 605458.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71636',
#    'naacc': None,
#    'lat': 4688613.416399388,
#    'raw': {'OBJECTID': 29,
#     'pointid': 29,
#     'grid_code': 71636,
#     'Survey_ID': 74246,
#     'NAACC_ID': 71636,
#     'Lat': 42.342777,
#     'Long': -73.719741,
#     'Rd_Name': 'Falls Road',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 2.1,
#     'In_B': 1.7,
#     'HW': 3.6,
#     'Slope': 1,
#     'Length': 41.3,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 2,
#     'Out_B': 1.2,
#     'Crossing_T': 'Culvert',
#     'Comments': 'plastic pipe runs through structure and far upstream and downstream. Wall of phragmites downstream',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '133C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 605458.2765349215, 'y': 4688613.416399388}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 625718.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '70991',
#    'naacc': None,
#    'lat': 4688513.416399386,
#    'raw': {'OBJECTID': 30,
#     'pointid': 30,
#     'grid_code': 70991,
#     'Survey_ID': 73621,
#     'NAACC_ID': 70991,
#     'Lat': 42.338645,
#     'Long': -73.473794,
#     'Rd_Name': 'Beebe Forest Road',
#     'Culv_Mat': 'Metal',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 3,
#     'In_B': 3,
#     'HW': 1.2,
#     'Slope': 0.2,
#     'Length': 16,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 3,
#     'Out_B': 3,
#     'Crossing_T': 'Culvert',
#     'Comments': 'wetland on inlet side in between structure and pond. beautiful stream downstream. shaded area downstream',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '103C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 625718.2765349215, 'y': 4688513.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 605698.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71635',
#    'naacc': None,
#    'lat': 4688493.416399386,
#    'raw': {'OBJECTID': 31,
#     'pointid': 31,
#     'grid_code': 71635,
#     'Survey_ID': 74245,
#     'NAACC_ID': 71635,
#     'Lat': 42.341576,
#     'Long': -73.716767,
#     'Rd_Name': 'Falls Road',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 2,
#     'In_B': 2.1,
#     'HW': 2.1,
#     'Slope': 1.7,
#     'Length': 40.5,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 2,
#     'Out_B': 2,
#     'Crossing_T': 'Culvert',
#     'Comments': 'dam upsream. dam owner said 10 years ago flooded 2 feet above road surface. town put rocks around outlet  to help with flooding. flows into pond downstream',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '132C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 605698.2765349215, 'y': 4688493.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 608528.2765349196,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71646',
#    'naacc': None,
#    'lat': 4688323.416399386,
#    'raw': {'OBJECTID': 32,
#     'pointid': 32,
#     'grid_code': 71646,
#     'Survey_ID': 74254,
#     'NAACC_ID': 71646,
#     'Lat': 42.339716,
#     'Long': -73.682578,
#     'Rd_Name': 'Quinn Lane',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 1.5,
#     'In_B': 1.5,
#     'HW': 1.5,
#     'Slope': 0.3,
#     'Length': 30,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 1.5,
#     'Out_B': 1.5,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '140C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 608528.2765349196, 'y': 4688323.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 609168.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71643',
#    'naacc': None,
#    'lat': 4688323.416399386,
#    'raw': {'OBJECTID': 33,
#     'pointid': 33,
#     'grid_code': 71643,
#     'Survey_ID': 74252,
#     'NAACC_ID': 71643,
#     'Lat': 42.339715,
#     'Long': -73.674737,
#     'Rd_Name': 'Quinn Lane',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 4,
#     'In_B': 4.2,
#     'HW': 1,
#     'Slope': 3.2,
#     'Length': 40,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 4,
#     'Out_B': 4.1,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '137C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 609168.2765349215, 'y': 4688323.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 609298.2765349224,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71436',
#    'naacc': None,
#    'lat': 4688313.416399386,
#    'raw': {'OBJECTID': 34,
#     'pointid': 34,
#     'grid_code': 71436,
#     'Survey_ID': 74037,
#     'NAACC_ID': 71436,
#     'Lat': 42.339333,
#     'Long': -73.673037,
#     'Rd_Name': 'Quinn Lane',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 4,
#     'In_B': 4,
#     'HW': 1.5,
#     'Slope': 0.1,
#     'Length': 40,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 4,
#     'Out_B': 4,
#     'Crossing_T': 'Culvert',
#     'Comments': 'fish downstream',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '130C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 609298.2765349224, 'y': 4688313.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 611818.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71052',
#    'naacc': None,
#    'lat': 4688313.416399386,
#    'raw': {'OBJECTID': 35,
#     'pointid': 35,
#     'grid_code': 71052,
#     'Survey_ID': 73681,
#     'NAACC_ID': 71052,
#     'Lat': 42.339136,
#     'Long': -73.64258,
#     'Rd_Name': 'Johnson Road',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 2.5,
#     'In_B': 2.3,
#     'HW': 3,
#     'Slope': 8.1,
#     'Length': 29,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 2.3,
#     'Out_B': 1.7,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '118C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 611818.2765349206, 'y': 4688313.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 619208.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '73318',
#    'naacc': None,
#    'lat': 4688313.416399386,
#    'raw': {'OBJECTID': 36,
#     'pointid': 36,
#     'grid_code': 73318,
#     'Survey_ID': 76067,
#     'NAACC_ID': 73318,
#     'Lat': 42.338019,
#     'Long': -73.552777,
#     'Rd_Name': 'Beale Rd',
#     'Culv_Mat': 'Metal',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Elliptical',
#     'In_A': 9,
#     'In_B': 6.6,
#     'HW': 2.5,
#     'Slope': 0.2,
#     'Length': 48.8,
#     'Out_Shape': 'Pipe Arch/Elliptical Culvert',
#     'Out_A': 9.3,
#     'Out_B': 6.5,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '215C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 619208.2765349215, 'y': 4688313.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 609008.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71644',
#    'naacc': None,
#    'lat': 4688303.416399386,
#    'raw': {'OBJECTID': 37,
#     'pointid': 37,
#     'grid_code': 71644,
#     'Survey_ID': 74253,
#     'NAACC_ID': 71644,
#     'Lat': 42.339566,
#     'Long': -73.676662,
#     'Rd_Name': 'Quinn Lane',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 2,
#     'In_B': 2,
#     'HW': 1,
#     'Slope': 5.1,
#     'Length': 30,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 2,
#     'Out_B': 2,
#     'Crossing_T': 'Multiple Culvert',
#     'Comments': 'fish in front of inlet. cannot pass through culvert because perched and dry. inlets slightly wet but no flow',
#     'Flags': 2,
#     'Modeling_n': ' ',
#     'BarrierID': '138C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 609008.2765349206, 'y': 4688303.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 609348.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71651',
#    'naacc': None,
#    'lat': 4688263.416399386,
#    'raw': {'OBJECTID': 38,
#     'pointid': 38,
#     'grid_code': 71651,
#     'Survey_ID': 74259,
#     'NAACC_ID': 71651,
#     'Lat': 42.338841,
#     'Long': -73.672524,
#     'Rd_Name': 'Letter S Road',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 4,
#     'In_B': 4,
#     'HW': 0.5,
#     'Slope': 5.1,
#     'Length': 30,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 4,
#     'Out_B': 4.2,
#     'Crossing_T': 'Culvert',
#     'Comments': 'fish upstream and downstream',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '145C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 609348.2765349206, 'y': 4688263.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 619058.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '70370',
#    'naacc': None,
#    'lat': 4688233.4163993895,
#    'raw': {'OBJECTID': 39,
#     'pointid': 39,
#     'grid_code': 70370,
#     'Survey_ID': 72975,
#     'NAACC_ID': 70370,
#     'Lat': 42.337217,
#     'Long': -73.554562,
#     'Rd_Name': 'Beale Road',
#     'Culv_Mat': 'Metal',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Elliptical',
#     'In_A': 9.1,
#     'In_B': 6.5,
#     'HW': 2.5,
#     'Slope': 5.5,
#     'Length': 47,
#     'Out_Shape': 'Pipe Arch/Elliptical Culvert',
#     'Out_A': 9.1,
#     'Out_B': 6.5,
#     'Crossing_T': 'Culvert',
#     'Comments': 'concrete blocks to reduce erosion next to inlet. measured outlet by walking through. fish and crayfish seen at inlet. bedrock after outlet',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '61C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 619058.2765349206, 'y': 4688233.4163993895}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 611748.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71050',
#    'naacc': None,
#    'lat': 4688153.416399388,
#    'raw': {'OBJECTID': 40,
#     'pointid': 40,
# ...
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '164C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 612958.2765349215, 'y': 4662993.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 603258.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71928',
#    'naacc': None,
#    'lat': 4662583.416399386,
#    'raw': {'OBJECTID': 181,
#     'pointid': 181,
#     'grid_code': 71928,
#     'Survey_ID': 74581,
#     'NAACC_ID': 71928,
#     'Lat': 42.108644,
#     'Long': -73.750949,
#     'Rd_Name': 'unnamed driveway off Taghkanic Rd',
#     'Culv_Mat': 'Metal',
#     'In_Type': 'Other',
#     'In_Shape': 'Round',
#     'In_A': 2.5,
#     'In_B': 2.5,
#     'HW': 3,
#     'Slope': 2.1,
#     'Length': 23,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 2.5,
#     'Out_B': 2.5,
#     'Crossing_T': 'Culvert',
#     'Comments': 'bankfull estimated due to low swamp area upstream',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '168C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 603258.2765349215, 'y': 4662583.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 611888.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71683',
#    'naacc': None,
#    'lat': 4662543.416399386,
#    'raw': {'OBJECTID': 182,
#     'pointid': 182,
#     'grid_code': 71683,
#     'Survey_ID': 74329,
#     'NAACC_ID': 71683,
#     'Lat': 42.10698,
#     'Long': -73.646541,
#     'Rd_Name': 'New Forge Rd',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 1.3,
#     'In_B': 1.3,
#     'HW': 1.5,
#     'Slope': 4.2,
#     'Length': 35.1,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 1.3,
#     'Out_B': 1.3,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '153C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 611888.2765349206, 'y': 4662543.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 603428.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '69958',
#    'naacc': None,
#    'lat': 4662513.4163993895,
#    'raw': {'OBJECTID': 183,
#     'pointid': 183,
#     'grid_code': 69958,
#     'Survey_ID': 72490,
#     'NAACC_ID': 69958,
#     'Lat': 42.107891,
#     'Long': -73.748731,
#     'Rd_Name': 'Taghkanic Road',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 2.1,
#     'In_B': 1.5,
#     'HW': 5.74,
#     'Slope': 1.7,
#     'Length': 52,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 2,
#     'Out_B': 2,
#     'Crossing_T': 'Culvert',
#     'Comments': 'Bankfull taken with one measurement due to excessive vegetative growth upstream.',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '40C19',
#     'BarrierID_': -175.632282979,
#     'BarrierID1': 9751785204900000,
#     'geometry': {'x': 603428.2765349206, 'y': 4662513.4163993895}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 606058.2765349224,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '69383',
#    'naacc': None,
#    'lat': 4662443.416399388,
#    'raw': {'OBJECTID': 184,
#     'pointid': 184,
#     'grid_code': 69383,
#     'Survey_ID': 71786,
#     'NAACC_ID': 69383,
#     'Lat': 42.106798,
#     'Long': -73.71735,
#     'Rd_Name': 'Taconic State parkway Northbound',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Wingwall',
#     'In_Shape': 'Round',
#     'In_A': 4,
#     'In_B': 4,
#     'HW': 3.12,
#     'Slope': 8.4,
#     'Length': 84.9,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 4,
#     'Out_B': 4,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '23C19',
#     'BarrierID_': 69.7761579946,
#     'BarrierID1': 9751785204900000,
#     'geometry': {'x': 606058.2765349224, 'y': 4662443.416399388}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 606018.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71924',
#    'naacc': None,
#    'lat': 4662383.416399386,
#    'raw': {'OBJECTID': 185,
#     'pointid': 185,
#     'grid_code': 71924,
#     'Survey_ID': 74573,
#     'NAACC_ID': 71924,
#     'Lat': 42.106297,
#     'Long': -73.717867,
#     'Rd_Name': 'Taconic St Parkway S',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Headwall',
#     'In_Shape': 'Round',
#     'In_A': 3.9,
#     'In_B': 4,
#     'HW': 3.5,
#     'Slope': 3.5,
#     'Length': 76.5,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 4,
#     'Out_B': 4,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '165C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 606018.2765349215, 'y': 4662383.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 602488.2765349224,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '69959',
#    'naacc': None,
#    'lat': 4662303.4163993895,
#    'raw': {'OBJECTID': 186,
#     'pointid': 186,
#     'grid_code': 69959,
#     'Survey_ID': 72491,
#     'NAACC_ID': 69959,
#     'Lat': 42.106097,
#     'Long': -73.76016,
#     'Rd_Name': 'Dranbauer road',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 2,
#     'In_B': 2,
#     'HW': 2.57,
#     'Slope': 4.6,
#     'Length': 53.7,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 2.2,
#     'Out_B': 2,
#     'Crossing_T': 'Culvert',
#     'Comments': 'Stream forks off just upstream, only took one bankfull measurement.',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '41C19',
#     'BarrierID_': -175.632282979,
#     'BarrierID1': 9751785204900000,
#     'geometry': {'x': 602488.2765349224, 'y': 4662303.4163993895}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 604628.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '69960',
#    'naacc': None,
#    'lat': 4662253.416399388,
#    'raw': {'OBJECTID': 187,
#     'pointid': 187,
#     'grid_code': 69960,
#     'Survey_ID': 72493,
#     'NAACC_ID': 69960,
#     'Lat': 42.105588,
#     'Long': -73.734574,
#     'Rd_Name': 'Sapok Road',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 2.5,
#     'In_B': 2.4,
#     'HW': 1.02,
#     'Slope': 0.4,
#     'Length': 40.2,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 2.6,
#     'Out_B': 2.5,
#     'Crossing_T': 'Culvert',
#     'Comments': 'At the outlet the pipe is corroded at the bottom.',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '42C19',
#     'BarrierID_': -175.632282979,
#     'BarrierID1': 9751785204900000,
#     'geometry': {'x': 604628.2765349206, 'y': 4662253.416399388}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 616598.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '64678',
#    'naacc': None,
#    'lat': 4661943.416399386,
#    'raw': {'OBJECTID': 188,
#     'pointid': 188,
#     'grid_code': 64678,
#     'Survey_ID': 66756,
#     'NAACC_ID': 64678,
#     'Lat': 42.101002,
#     'Long': -73.589809,
#     'Rd_Name': 'County Route 7',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Wingwall and Headwall',
#     'In_Shape': 'Box',
#     'In_A': 5.8,
#     'In_B': 3,
#     'HW': 2.5,
#     'Slope': 0.1,
#     'Length': 43,
#     'Out_Shape': 'Box Culvert',
#     'Out_A': 5.4,
#     'Out_B': 3.4,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '8C19',
#     'BarrierID_': 12.4803784815,
#     'BarrierID1': 9751785204900000,
#     'geometry': {'x': 616598.2765349206, 'y': 4661943.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 605858.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71926',
#    'naacc': None,
#    'lat': 4661533.416399388,
#    'raw': {'OBJECTID': 189,
#     'pointid': 189,
#     'grid_code': 71926,
#     'Survey_ID': 74578,
#     'NAACC_ID': 71926,
#     'Lat': 42.098546,
#     'Long': -73.719828,
#     'Rd_Name': 'Route 15',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Mitered to Slope',
#     'In_Shape': 'Round',
#     'In_A': 1.4,
#     'In_B': 1.2,
#     'HW': 3.5,
#     'Slope': 2.1,
#     'Length': 38,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 1.3,
#     'Out_B': 1.3,
#     'Crossing_T': 'Culvert',
#     'Comments': 'Possibly road drainage, could not find upstream channel, it was flowing heavily probably because we got a lot of rain last night,',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '167C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 605858.2765349206, 'y': 4661533.416399388}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 609958.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '71682',
#    'naacc': None,
#    'lat': 4661523.416399388,
#    'raw': {'OBJECTID': 190,
#     'pointid': 190,
#     'grid_code': 71682,
#     'Survey_ID': 74327,
#     'NAACC_ID': 71682,
#     'Lat': 42.098009,
#     'Long': -73.670102,
#     'Rd_Name': 'Old Forge Road Spur',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 2,
#     'In_B': 2,
#     'HW': 1,
#     'Slope': 5.2,
#     'Length': 39.8,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 21,
#     'Out_B': 2,
#     'Crossing_T': 'Culvert',
#     'Comments': 'Appears to be draining a narrow roadside ditch, into the stream across the road, so probably road drainage, no obvious flowline. There is another pipe approximately 1.5 ft from the inlet, we did not assess because appeared to be an outfall draining from',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '152C19',
#     'BarrierID_': 0,
#     'BarrierID1': 0,
#     'geometry': {'x': 609958.2765349215, 'y': 4661523.416399388}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 614268.2765349206,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '64677',
#    'naacc': None,
#    'lat': 4661163.4163993895,
#    'raw': {'OBJECTID': 191,
#     'pointid': 191,
#     'grid_code': 64677,
#     'Survey_ID': 66755,
#     'NAACC_ID': 64677,
#     'Lat': 42.094236,
#     'Long': -73.617978,
#     'Rd_Name': 'Thompkins Road',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 1.3,
#     'In_B': 1.4,
#     'HW': 1.3,
#     'Slope': -1,
#     'Length': 36.7,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 1.3,
#     'Out_B': 1.3,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '7C19',
#     'BarrierID_': 12.4803784815,
#     'BarrierID1': 9751785204900000,
#     'geometry': {'x': 614268.2765349206, 'y': 4661163.4163993895}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 616218.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '64676',
#    'naacc': None,
#    'lat': 4660743.416399384,
#    'raw': {'OBJECTID': 192,
#     'pointid': 192,
#     'grid_code': 64676,
#     'Survey_ID': 66754,
#     'NAACC_ID': 64676,
#     'Lat': 42.090356,
#     'Long': -73.594754,
#     'Rd_Name': 'Bettman Lane',
#     'Culv_Mat': 'Metal',
#     'In_Type': 'Headwall',
#     'In_Shape': 'Round',
#     'In_A': 3.1,
#     'In_B': 2.8,
#     'HW': 2.7,
#     'Slope': 0.4,
#     'Length': 41,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 3,
#     'Out_B': 3,
#     'Crossing_T': 'Culvert',
#     'Comments': 'Passerby noted that this is a private road',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '6C19',
#     'BarrierID_': -44.8154010316,
#     'BarrierID1': 9751785204900000,
#     'geometry': {'x': 616218.2765349215, 'y': 4660743.416399384}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 616218.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '64675',
#    'naacc': None,
#    'lat': 4660573.416399386,
#    'raw': {'OBJECTID': 193,
#     'pointid': 193,
#     'grid_code': 64675,
#     'Survey_ID': 66753,
#     'NAACC_ID': 64675,
#     'Lat': 42.088749,
#     'Long': -73.594683,
#     'Rd_Name': 'Driveway',
#     'Culv_Mat': 'Metal',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 2.5,
#     'In_B': 2,
#     'HW': 0.3,
#     'Slope': 1.1,
#     'Length': 48.2,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 2.5,
#     'Out_B': 2.5,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '5C19',
#     'BarrierID_': -44.8154010316,
#     'BarrierID1': 9751785204900000,
#     'geometry': {'x': 616218.2765349215, 'y': 4660573.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 616308.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '64674',
#    'naacc': None,
#    'lat': 4660573.416399386,
#    'raw': {'OBJECTID': 194,
#     'pointid': 194,
#     'grid_code': 64674,
#     'Survey_ID': 66752,
#     'NAACC_ID': 64674,
#     'Lat': 42.088467,
#     'Long': -73.593666,
#     'Rd_Name': 'County Route 7',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 1.5,
#     'In_B': 1.5,
#     'HW': 1.4,
#     'Slope': 2.6,
#     'Length': 45,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 1.3,
#     'Out_B': 1.3,
#     'Crossing_T': 'Culvert',
#     'Comments': 'Storm drain',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '4C19',
#     'BarrierID_': -44.8154010316,
#     'BarrierID1': 9751785204900000,
#     'geometry': {'x': 616308.2765349215, 'y': 4660573.416399386}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 616218.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '64673',
#    'naacc': None,
#    'lat': 4660293.416399384,
#    'raw': {'OBJECTID': 195,
#     'pointid': 195,
#     'grid_code': 64673,
#     'Survey_ID': 66751,
#     'NAACC_ID': 64673,
#     'Lat': 42.08623,
#     'Long': -73.594912,
#     'Rd_Name': 'County Route 7',
#     'Culv_Mat': 'Concrete',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 4,
#     'In_B': 4,
#     'HW': 4,
#     'Slope': 2.4,
#     'Length': 101,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 4,
#     'Out_B': 3.2,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '3C19',
#     'BarrierID_': -44.8154010316,
#     'BarrierID1': 9751785204900000,
#     'geometry': {'x': 616218.2765349215, 'y': 4660293.416399384}},
#    'group_id': None},
#   {'shed': None,
#    'analytics': [],
#    'capacity': None,
#    'spatial_ref_code': 26918,
#    'lng': 614088.2765349215,
#    'include': True,
#    'validation_errors': {},
#    'notes': [],
#    'uid': '64672',
#    'naacc': None,
#    'lat': 4660103.416399386,
#    'raw': {'OBJECTID': 196,
#     'pointid': 196,
#     'grid_code': 64672,
#     'Survey_ID': 66750,
#     'NAACC_ID': 64672,
#     'Lat': 42.084814,
#     'Long': -73.620643,
#     'Rd_Name': 'Banor Road',
#     'Culv_Mat': 'Plastic',
#     'In_Type': 'Projecting',
#     'In_Shape': 'Round',
#     'In_A': 3,
#     'In_B': 3,
#     'HW': 1.2,
#     'Slope': 3.1,
#     'Length': 31,
#     'Out_Shape': 'Round Culvert',
#     'Out_A': 3,
#     'Out_B': 3,
#     'Crossing_T': 'Culvert',
#     'Comments': ' ',
#     'Flags': 1,
#     'Modeling_n': ' ',
#     'BarrierID': '2C19',
#     'BarrierID_': -44.8154010316,
#     'BarrierID1': 9751785204900000,
#     'geometry': {'x': 614088.2765349215, 'y': 4660103.416399386}},
#    'group_id': None}]}

# %%
points = [PointSchema().load(p) for p in test_points['points']]
points[0]
# Out:
# Point(uid='70978', lat=4690423.416399388, lng=618918.2765349224, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=Shed(uid='70978', group_id=None, area_sqkm=3198.260236505569, avg_slope_pct=16.102196872234344, avg_cn=77.75, max_fl=88.260292053223, rainfall=[Rainfall(freq=1, dur='24hr', value=59.74079999999999), Rainfall(freq=2, dur='24hr', value=74.1172), Rainfall(freq=5, dur='24hr', value=97.6122), Rainfall(freq=10, dur='24hr', value=117.1194), Rainfall(freq=25, dur='24hr', value=143.9672), Rainfall(freq=50, dur='24hr', value=163.80459999999997), Rainfall(freq=100, dur='24hr', value=185.3438), Rainfall(freq=200, dur='24hr', value=211.63279999999997), Rainfall(freq=500, dur='24hr', value=251.94259999999997), Rainfall(freq=1000, dur='24hr', value=286.61359999999996)], inlet_geom=None, shed_geom=None, shed_polygon_filepath='in_memory\\basin70978_dissolved', shed_raster_filepath='in_memory/catchment_70978.tif'), analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 1, 'pointid': 1, 'grid_code': 70978, 'Survey_ID': 73607, 'NAACC_ID': 70978, 'Lat': 42.35717, 'Long': -73.556041, 'Rd_Name': 'Raup Road', 'Culv_Mat': 'Metal', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 4.9, 'In_B': 4.8, 'HW': 2, 'Slope': 2.8, 'Length': 26, 'Out_Shape': 'Round Culvert', 'Out_A': 5.2, 'Out_B': 5.4, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '96C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 618918.2765349224, 'y': 4690423.416399388}})
