# %% [markdown]
# # Watershed Delineation Methods
#
# Run delineations for both the "series" and "parallel" approaches.

# %%
from pathlib import Path
import json
from statistics import mean
import math
from typing import List
from pprint import PrettyPrinter

from arcpy import FeatureSet, RecordSet, Raster, Describe, CreateUniqueName, EnvManager, SpatialReference
from arcpy.management import (
    MakeFeatureLayer, 
    SelectLayerByAttribute, 
    GetCount, 
    MakeTableView, 
    BuildRasterAttributeTable,
    Dissolve,
    AddFields,
    CreateFeatureclass
)
from arcpy.analysis import Buffer
from arcpy.sa import Watershed, FlowLength, ZonalStatisticsAsTable, SetNull, IsNull
from arcpy.da import SearchCursor, InsertCursor
from arcpy.conversion import RasterToPolygon, JSONToFeatures

from dataclasses import dataclass, field, asdict
from marshmallow import Schema, fields, EXCLUDE, pre_load
from marshmallow_dataclass import class_schema

from tqdm.notebook import tqdm
import petl as etl

# import arcgis

# %%
pp = PrettyPrinter(indent=2).pprint

# %%
from arcpy import env
env.overwriteOutput = True

# %%
wd = Path(r"D:\Dropbox (CivicMapper)\Projects\202004-02 Cornell Modeling\3 - Production\tool outputs")
test_results_dir = wd / "c19 tests" / "test_results"

rainfall_rasters_config = Path(r"D:\Dropbox (CivicMapper)\Projects\202004-02 Cornell Modeling\3 - Production\tool outputs\c19 tests\noaa_rainfall\noaa_rainfall_rasters_config_ne.json")

inlets = wd / "c19 tests"  / "c19_snapped_points.shp"
dem = wd / "c19 tests" / "dem_clip_simple.tif"
fd = wd / "c19 tests" / "dem_clip_simple_flowdir.tif"
cn = wd / "c19 tests" / "curveno.tif"
slope = wd / "c19 tests" / "dem_slope.tif"

pour_point_field = "NAACC_ID"
out_catchment_polygons_simplify = False

# %% [markdown]
# ## Models:

# %%
@dataclass
class Rainfall:
    """storm frequency interval with rainfall values and rainfall-dependent 
    analytical results from the calculators
    """

    freq: int = None
    dur: str = None
    value: float = None
        
RainfallSchema = class_schema(Rainfall)

# %%
@dataclass
class Shed:
    """Characteristics of a single point's contributing area
    """
    # unique id field, derived from the outlet point; the value from the
    # "pour_point_field". For NAACC-based culvert modeling, this is the
    # NAACC Naacc_Culvert_Id field
    uid: str = None
    
    # a group id field. non-unique ID field that indicates groups of related
    # outlets. Used primarily for NAACC-based culvert modeling, this is the
    # NAACC Survey_Id field
    group_id: str = None

    # characteristics used for calculating peak flow
    area_sqkm: float = None# <area of inlet's catchment in square km>
    avg_slope_pct: float = None # <average slope of DEM in catchment>
    avg_cn: float = None # <average curve number in the catchment>
    max_fl: float = None # <maximum flow length in the catchment>
    rainfall: List[Rainfall] = None # average rainfall in the catchment, for storm events

    # geometries
    inlet_geom: dict = None
    shed_geom: dict = None
    
    # for recording the location of intermediate geospatial output files
    shed_polygon_filepath: str = None
    shed_raster_filepath: str = None
        
ShedSchema = class_schema(Shed)

# %%
@dataclass
class Point:
    """Basic model for points used as source delineations for peak-flow-calcs;
    minimal attributes required.
    """

    # unique id field, derived from the outlet point; the value from the
    # "pour_point_field". For NAACC-based culvert modeling, this is the
    # NAACC Naacc_Culvert_Id field
    uid: str

    lat: float = None
    lng: float = None
    spatial_ref_code: int = None

    # a group id field. non-unique ID field that indicates groups of related
    # outlets. Used primarily for NAACC-based culvert modeling, this is the
    # NAACC Survey_Id field
    group_id: str = None

    # optionally extend with NAACC & capacity attributes
    # naacc: NaaccCulvert = None
    # capacity: Capacity = None
    naacc: dict = None
    capacity: dict = None

    # optionally extend with the Shed and its characteristics
    shed: Shed = None

    # rainfall frequency-based analytical results for the point
    analytics: List[Rainfall] = field(default_factory=list)

    # flags, errors, and notes
    include: bool = True
    validation_errors: dict = field(default_factory=dict)
    notes: list = field(default_factory=list)

    # place to store the raw input
    raw: dict = None

# %%
def fc_to_petl_table(
    feature_class, 
    include_geom=False,
    return_featureset=True
    ):
    """Convert an Esri Feature Class to a PETL table object. Optionally,
    return the FeatureSet used to create the PETL table.

    Convert an Esri Feature Class to a PETL table object.

    :param feature_class: [description]
    :type feature_class: [type]
    :param include_geom: [description], defaults to False
    :param include_geom: bool, optional
    :param return_featureset: return Esri FeatureSet, defaults to False
    :param return_featureset: bool, optional        
    :return: tuple containing an PETL Table object and FeatureSet
    :rtype: Tuple(petl.Table, FeatureSet)
    """
    print("Reading {0} into a PETL table object".format(feature_class))
    
    feature_class = str(inlets)
    feature_set = FeatureSet(feature_class)
    # convert the FeatureSet object to a python dictionary
    fs = json.loads(feature_set.JSON)

    # describe the feature class
    described_fc = Describe(feature_class)
    # get a list of field objects
    field_objs = described_fc.fields

    # make a list of fields that doesn't include the Object ID field
    all_fields = [f for f in field_objs if f.name != described_fc.OIDFieldName]
    # make a list of field names, excluding geometry and the OID field
    attr_fields = [f.name for f in all_fields if f.type not in ['Geometry', 'Shape']]
    # then add 'geometry' to that list, since it will be present in the features in the FeatureSet
    attr_fields.append('geometry')
    
    table = etl\
        .fromdicts(fs['features'])\
        .unpackdict('attributes')\
        .cut(*attr_fields)

    if return_featureset:
        return table, feature_set
    else:
        return table, None

# %%
def create_geodata_from_points(
    points, 
    output_points_filepath=None,
    as_dict=True,
    default_spatial_ref_code=4326
    ):
    """from a list of Drain-It Point objects, create an ArcPy FeatureSet,
    for use in other ArcPy GP tools.

    :param points: list of drainit.models.Point objects. Only the uid and group_id are used here; extended attributes from naacc aren't used.
    :type points: List[Point]
    :param output_points_filepath: optional path to save points to file on disk, defaults to None
    :type output_points_filepath: str, optional
    :param as_dict: return the geodata as geoservices JSON as Python dictionary, defaults to True
    :type as_dict: bool, optional
    :return: geoservices JSON as Python dictionary; FeatureSet object if as_dict is False
    :rtype: dict
    """

    with EnvManager(overwriteOutput=True):

        #get the spatial ref from the first available point
        p_srs = [p.spatial_ref_code for p in points if p.spatial_ref_code is not None]
        print(p_srs)
        if len(p_srs) > 0:
            try:
                spatial_ref = SpatialReference(p_srs[0])
            except:
                spatial_ref = SpatialReference(default_spatial_ref_code)
        else:
            spatial_ref = SpatialReference(default_spatial_ref_code)
            
        print(spatial_ref)

        # Create an in_memory feature class to initially contain the points
        feature_class = CreateFeatureclass(
            out_path="in_memory", 
            out_name="temp_drainit_points", 
            geometry_type="POINT",
            spatial_reference=spatial_ref
        )

        AddFields(
            feature_class, 
            [
                #[Field Name, Field Type]
                ['uid', 'TEXT'],
                ['group_id', 'TEXT'],
            ]
        )
        
        print(points)

        # Open an insert cursor
        with InsertCursor(feature_class, ['uid', 'group_id', "SHAPE@XY"]) as cursor:
            # Iterate through list of coordinates and add to cursor
            for pt in points:
                row = [pt.uid, pt.group_id, (pt.lng, pt.lat)]
                cursor.insertRow(row)

        # Create a FeatureSet object and load in_memory feature class JSON as dict
        feature_set = FeatureSet()
        feature_set.load(feature_class)

    if output_points_filepath:
        feature_set.save(output_points_filepath)

    # return the dictionary (geoservices JSON as Python dictionary)
    if as_dict:
        return json.loads(feature_set.JSON)
    else:
        return feature_set

def extract_points_from_geodata(
    points_filepath, 
    uid_field,
    is_naacc=False,
    group_id_field=None,
    output_points_filepath=None
    ):
    """from any geodata input file, create a list of Point objects and a 
    ArcGIS FeatureSet object
    """

    # # handle inputs that are from an interactive selection in ArcMap/Pro
    if isinstance(points_filepath, FeatureSet):
        print("Reading from interactive selection")
    else:
        print('Reading from file')

    # extract feature class to a PETL table and a FeatureSet
    raw_table, feature_set = fc_to_petl_table(
        points_filepath,
        include_geom=True,
        return_featureset=True
    )

    # convert the FeatureSet to its JSON representation
    feature_set_json = json.loads(feature_set.JSON)

    # get the spatial reference code from the FeatureSet JSON
    spatial_ref_code = feature_set_json.get('spatialReference', {}).get('wkid', None)

    # if this is geodata that follows the NAACC format, we use the NAACC
    # etl function to transform the table to a list of Point objects
    # with nested NAACC and capacity calc-ready attributes where possible
    # (This is workflow for Culvert Capacity when geodata is provided 
    # instead of a CSV)
    if is_naacc:
        print('reading points and capturing NAACC attributes')
        points = etl_naacc_table(
            naacc_petl_table=raw_table,
            spatial_ref_code=spatial_ref_code
        )

    # Otherwise we transform the raw table to a list of Point objects here
    # (This is workflow for Peak-Flow)
    else:
        print('reading points')
        points = []
        for idx, r in enumerate(list(etl.dicts(raw_table))):
            point_kwargs = dict(
                uid=r[uid_field],
                lat=float(r["geometry"]['y']),
                lng=float(r["geometry"]['x']),
                spatial_ref_code=spatial_ref_code,
                include=True,
                raw=r
            )
            if group_id_field:
                point_kwargs['group_id'] = r[group_id_field],

            p = Point(**point_kwargs)
            points.append(p)

    if output_points_filepath:
        # finally, save it out
        self.msg('saving points')
        # save a copy of the points feature_set to the output location
        feature_set.save(output_points_filepath)

    # return the list of Point objects and a dict version of the FeatureSet
    return points, feature_set_json, spatial_ref_code

# %% [markdown]
# ## Read the Points
#
# * as a FeatureSet
# * as a PETL table

# %%
points, fs, sr = extract_points_from_geodata(str(inlets), "NAACC_ID")
# Out:
# Reading from file
# Reading D:\Dropbox (CivicMapper)\Projects\202004-02 Cornell Modeling\3 - Production\tool outputs\c19 tests\c19_snapped_points.shp into a PETL table object
# reading points

# %%
points
# Out:
# [Point(uid=70978, lat=4690423.416399388, lng=618918.2765349224, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 1, 'pointid': 1, 'grid_code': 70978, 'Survey_ID': 73607, 'NAACC_ID': 70978, 'Lat': 42.35717, 'Long': -73.556041, 'Rd_Name': 'Raup Road', 'Culv_Mat': 'Metal', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 4.9, 'In_B': 4.8, 'HW': 2, 'Slope': 2.8, 'Length': 26, 'Out_Shape': 'Round Culvert', 'Out_A': 5.2, 'Out_B': 5.4, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '96C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 618918.2765349224, 'y': 4690423.416399388}}),
#  Point(uid=71056, lat=4690193.416399388, lng=610968.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 2, 'pointid': 2, 'grid_code': 71056, 'Survey_ID': 73685, 'NAACC_ID': 71056, 'Lat': 42.356053, 'Long': -73.652552, 'Rd_Name': 'Mile Hill Road', 'Culv_Mat': 'Concrete', 'In_Type': 'Mitered to Slope', 'In_Shape': 'Round', 'In_A': 1.5, 'In_B': 1.3, 'HW': 5, 'Slope': -1, 'Length': 42, 'Out_Shape': 'Round Culvert', 'Out_A': 1.5, 'Out_B': 1.5, 'Crossing_T': 'Culvert', 'Comments': 'headwall on outlet side. large pond downstream', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '121C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 610968.2765349215, 'y': 4690193.416399388}}),
#  Point(uid=70979, lat=4690163.416399388, lng=618868.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 3, 'pointid': 3, 'grid_code': 70979, 'Survey_ID': 73608, 'NAACC_ID': 70979, 'Lat': 42.354772, 'Long': -73.556639, 'Rd_Name': 'Red Rock Road', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 6, 'In_B': 5.1, 'HW': 7, 'Slope': 6.8, 'Length': 35, 'Out_Shape': 'Box Culvert', 'Out_A': 5.9, 'Out_B': 5, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '97C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 618868.2765349215, 'y': 4690163.416399388}}),
#  Point(uid=73324, lat=4690093.416399386, lng=618848.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 4, 'pointid': 4, 'grid_code': 73324, 'Survey_ID': 76071, 'NAACC_ID': 73324, 'Lat': 42.354158, 'Long': -73.556776, 'Rd_Name': 'Old road', 'Culv_Mat': 'Combination', 'In_Type': 'Wingwall', 'In_Shape': 'Box', 'In_A': 19.9, 'In_B': 7.1, 'HW': 0, 'Slope': -1, 'Length': 20.4, 'Out_Shape': 'Box/Bridge with Abutments', 'Out_A': 20, 'Out_B': 7.2, 'Crossing_T': 'Bridge', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '220C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 618848.2765349206, 'y': 4690093.416399386}}),
#  Point(uid=71049, lat=4690083.416399386, lng=612348.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 5, 'pointid': 5, 'grid_code': 71049, 'Survey_ID': 73678, 'NAACC_ID': 71049, 'Lat': 42.354929, 'Long': -73.635924, 'Rd_Name': 'Church Sreet', 'Culv_Mat': 'Concrete', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 3, 'In_B': 3, 'HW': 1.5, 'Slope': 3, 'Length': 40, 'Out_Shape': 'Round Culvert', 'Out_A': 3, 'Out_B': 3, 'Crossing_T': 'Culvert', 'Comments': 'buried upstream under field. fish in scour pool', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '115C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 612348.2765349206, 'y': 4690083.416399386}}),
#  Point(uid=70962, lat=4689973.416399388, lng=615548.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 6, 'pointid': 6, 'grid_code': 70962, 'Survey_ID': 73590, 'NAACC_ID': 70962, 'Lat': 42.353513, 'Long': -73.59691, 'Rd_Name': 'Coleman Street', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 5, 'In_B': 5, 'HW': 5.5, 'Slope': 1.3, 'Length': 65, 'Out_Shape': 'Box Culvert', 'Out_A': 5, 'Out_B': 5, 'Crossing_T': 'Culvert', 'Comments': 'considerable erosion upstream and downstream. concrete slabs laying on banks of upstream culvert visible in upstream photo', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '82C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 615548.2765349215, 'y': 4689973.416399388}}),
#  Point(uid=70934, lat=4689953.416399388, lng=615268.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 7, 'pointid': 7, 'grid_code': 70934, 'Survey_ID': 73567, 'NAACC_ID': 70934, 'Lat': 42.353382, 'Long': -73.600233, 'Rd_Name': 'Payn Road', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 8.5, 'In_B': 1.7, 'HW': 2, 'Slope': 8.1, 'Length': 160, 'Out_Shape': 'Unknown', 'Out_A': -1, 'Out_B': -1, 'Crossing_T': 'Partially Inaccessible', 'Comments': 'looks buried under yard on outlet side. cant see far through inlet because curves to the left. possibly outlets into yard of house number 30. inlet is across the street from houses 26 and 28. Neighbor says house number 30 owner is 78 yrs old and refuses', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '67C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 615268.2765349206, 'y': 4689953.416399388}}),
#  Point(uid=70964, lat=4689873.416399386, lng=615198.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 8, 'pointid': 8, 'grid_code': 70964, 'Survey_ID': 73592, 'NAACC_ID': 70964, 'Lat': 42.352664, 'Long': -73.601273, 'Rd_Name': 'Elm Street', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 8, 'In_B': 3.2, 'HW': 2.2, 'Slope': 1.9, 'Length': 40, 'Out_Shape': 'Box Culvert', 'Out_A': 8, 'Out_B': 5, 'Crossing_T': 'Culvert', 'Comments': 'small fish and frogs in stream. neighbor says blue heron uses stream. drain grate in between structure and Payn St floods road, sidewalk and yard of house 5. Flooding happens when structure on Payne st floods', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '84C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 615198.2765349215, 'y': 4689873.416399386}}),
#  Point(uid=72494, lat=4689843.416399386, lng=614758.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 9, 'pointid': 9, 'grid_code': 72494, 'Survey_ID': 75154, 'NAACC_ID': 72494, 'Lat': 42.352439, 'Long': -73.606888, 'Rd_Name': 'Hudson Plaza', 'Culv_Mat': 'Concrete', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 2, 'In_B': 1.7, 'HW': 1, 'Slope': 8.1, 'Length': 100, 'Out_Shape': 'Round Culvert', 'Out_A': 2, 'Out_B': 1.5, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '197C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 614758.2765349215, 'y': 4689843.416399386}}),
#  Point(uid=70995, lat=4689743.416399388, lng=620528.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 10, 'pointid': 10, 'grid_code': 70995, 'Survey_ID': 73624, 'NAACC_ID': 70995, 'Lat': 42.350532, 'Long': -73.53654, 'Rd_Name': 'Ten Broek Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 4, 'In_B': 3.8, 'HW': 2.8, 'Slope': 9.1, 'Length': 40, 'Out_Shape': 'Round Culvert', 'Out_A': 3.9, 'Out_B': 3.8, 'Crossing_T': 'Culvert', 'Comments': 'driveway culvert upstream. lots of erosion downstream', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '107C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 620528.2765349206, 'y': 4689743.416399388}}),
#  Point(uid=72495, lat=4689723.416399388, lng=614888.2765349224, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 11, 'pointid': 11, 'grid_code': 72495, 'Survey_ID': 75155, 'NAACC_ID': 72495, 'Lat': 42.351419, 'Long': -73.605115, 'Rd_Name': 'Hudson Plaza', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 2, 'In_B': 2, 'HW': 1.2, 'Slope': 2.4, 'Length': 145, 'Out_Shape': 'Round Culvert', 'Out_A': 2, 'Out_B': 2, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '198C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 614888.2765349224, 'y': 4689723.416399388}}),
#  Point(uid=72496, lat=4689633.416399386, lng=614998.2765349224, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 12, 'pointid': 12, 'grid_code': 72496, 'Survey_ID': 75156, 'NAACC_ID': 72496, 'Lat': 42.350545, 'Long': -73.603894, 'Rd_Name': 'Dardess road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 2.5, 'In_B': 2.5, 'HW': 2, 'Slope': 0.5, 'Length': 100, 'Out_Shape': 'Box Culvert', 'Out_A': 8, 'Out_B': 2.5, 'Crossing_T': 'Culvert', 'Comments': 'ID:c810800', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '199C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 614998.2765349224, 'y': 4689633.416399386}}),
#  Point(uid=73320, lat=4689473.416399388, lng=617188.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 13, 'pointid': 13, 'grid_code': 73320, 'Survey_ID': 76070, 'NAACC_ID': 73320, 'Lat': 42.348702, 'Long': -73.577014, 'Rd_Name': 'TSP', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 12, 'In_B': 14.2, 'HW': 12, 'Slope': 0.3, 'Length': 218, 'Out_Shape': 'Box Culvert', 'Out_A': 12, 'Out_B': 14, 'Crossing_T': 'Multiple Culvert', 'Comments': 'Debris jam clogging three cells. Only one functioning. Small Trib joins Punsit ~100 ft upstream of inlet. Large bar deposit at inlet', 'Flags': 4, 'Modeling_n': ' ', 'BarrierID': '216C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 617188.2765349215, 'y': 4689473.416399388}}),
#  Point(uid=72500, lat=4689443.416399386, lng=614958.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 14, 'pointid': 14, 'grid_code': 72500, 'Survey_ID': 75159, 'NAACC_ID': 72500, 'Lat': 42.348877, 'Long': -73.604209, 'Rd_Name': 'Payn Avenue', 'Culv_Mat': 'Metal', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 1.5, 'In_B': 1.2, 'HW': 1.5, 'Slope': 0.6, 'Length': 90, 'Out_Shape': 'Round Culvert', 'Out_A': 3, 'Out_B': 2.4, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '203C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 614958.2765349215, 'y': 4689443.416399386}}),
#  Point(uid=70150, lat=4689433.416399386, lng=617808.2765349196, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 15, 'pointid': 15, 'grid_code': 70150, 'Survey_ID': 72735, 'NAACC_ID': 70150, 'Lat': 42.348382, 'Long': -73.569626, 'Rd_Name': 'Route 203', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 18, 'In_B': 8.5, 'HW': 2.5, 'Slope': -1, 'Length': 25, 'Out_Shape': 'Box/Bridge with Abutments', 'Out_A': 18, 'Out_B': 8, 'Crossing_T': 'Culvert', 'Comments': 'code 840941. inaccessible for slope and inlet and outlet pictures. steep drop off hidden by vines and other vegetation', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '54C19', 'BarrierID_': -118.336503466, 'BarrierID1': 9751785204900000, 'geometry': {'x': 617808.2765349196, 'y': 4689433.416399386}}),
#  Point(uid=70994, lat=4689423.416399386, lng=623138.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 16, 'pointid': 16, 'grid_code': 70994, 'Survey_ID': 73623, 'NAACC_ID': 70994, 'Lat': 42.347303, 'Long': -73.504827, 'Rd_Name': 'Stonewall Road', 'Culv_Mat': 'Metal', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 7.2, 'In_B': 7.3, 'HW': 1, 'Slope': 6.1, 'Length': 52, 'Out_Shape': 'Round Culvert', 'Out_A': 7.3, 'Out_B': 7.1, 'Crossing_T': 'Culvert', 'Comments': 'Fish next to outlet. waterfall cascade over rocks upstream', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '106C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 623138.2765349215, 'y': 4689423.416399386}}),
#  Point(uid=71652, lat=4689383.416399386, lng=608798.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 17, 'pointid': 17, 'grid_code': 71652, 'Survey_ID': 74261, 'NAACC_ID': 71652, 'Lat': 42.349241, 'Long': -73.678983, 'Rd_Name': 'Letter S Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 1.5, 'In_B': 1.5, 'HW': 1.5, 'Slope': 1.2, 'Length': 40, 'Out_Shape': 'Round Culvert', 'Out_A': 1.5, 'Out_B': 1.5, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '146C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 608798.2765349206, 'y': 4689383.416399386}}),
#  Point(uid=72502, lat=4689293.416399388, lng=614908.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 18, 'pointid': 18, 'grid_code': 72502, 'Survey_ID': 75161, 'NAACC_ID': 72502, 'Lat': 42.347581, 'Long': -73.604898, 'Rd_Name': 'Price Chopper Drive', 'Culv_Mat': 'Concrete', 'In_Type': 'Headwall', 'In_Shape': 'Box', 'In_A': 12, 'In_B': 4.5, 'HW': 3.5, 'Slope': 0.3, 'Length': 39, 'Out_Shape': 'Box Culvert', 'Out_A': 12, 'Out_B': 4.5, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '205C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 614908.2765349206, 'y': 4689293.416399388}}),
#  Point(uid=71003, lat=4689293.416399388, lng=623308.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 19, 'pointid': 19, 'grid_code': 71003, 'Survey_ID': 73632, 'NAACC_ID': 71003, 'Lat': 42.346303, 'Long': -73.502917, 'Rd_Name': 'Old Macedonia Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 4, 'In_B': 4, 'HW': 1, 'Slope': 5.6, 'Length': 40, 'Out_Shape': 'Round Culvert', 'Out_A': 4, 'Out_B': 4, 'Crossing_T': 'Culvert', 'Comments': 'second round pipe with fence for overflow off to the side. orange colored water', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '113C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 623308.2765349206, 'y': 4689293.416399388}}),
#  Point(uid=70996, lat=4689183.416399386, lng=621198.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 20, 'pointid': 20, 'grid_code': 70996, 'Survey_ID': 73625, 'NAACC_ID': 70996, 'Lat': 42.345451, 'Long': -73.528468, 'Rd_Name': 'Ten Broek Road', 'Culv_Mat': 'Concrete', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 2.9, 'In_B': 3, 'HW': 1.2, 'Slope': 0.5, 'Length': 38, 'Out_Shape': 'Round Culvert', 'Out_A': 3, 'Out_B': 3, 'Crossing_T': 'Culvert', 'Comments': 'larger fish darted out from underneath concrete slab', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '108C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 621198.2765349206, 'y': 4689183.416399386}}),
#  Point(uid=70973, lat=4689163.416399386, lng=623848.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 21, 'pointid': 21, 'grid_code': 70973, 'Survey_ID': 73600, 'NAACC_ID': 70973, 'Lat': 42.34483, 'Long': -73.496334, 'Rd_Name': 'Old Macedonia Road', 'Culv_Mat': 'Metal', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 5.8, 'In_B': 5.8, 'HW': 2, 'Slope': 6.5, 'Length': 30, 'Out_Shape': 'Round Culvert', 'Out_A': 6, 'Out_B': 5.9, 'Crossing_T': 'Culvert', 'Comments': 'bedrock at outlet. build up of logs and debris downstream. no evidence of beavers. road fill is mostly boulders and some gravel for road', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '92C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 623848.2765349206, 'y': 4689163.416399386}}),
#  Point(uid=70963, lat=4689143.416399386, lng=614848.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 22, 'pointid': 22, 'grid_code': 70963, 'Survey_ID': 73591, 'NAACC_ID': 70963, 'Lat': 42.346259, 'Long': -73.605656, 'Rd_Name': 'Taconic Place', 'Culv_Mat': 'Concrete', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 5, 'In_B': 5, 'HW': 5, 'Slope': 1.3, 'Length': 40, 'Out_Shape': 'Round Culvert', 'Out_A': 5, 'Out_B': 5, 'Crossing_T': 'Culvert', 'Comments': 'heron using scour pool shown in other picture 2', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '83C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 614848.2765349215, 'y': 4689143.416399386}}),
#  Point(uid=71001, lat=4689143.416399386, lng=622278.2765349196, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 23, 'pointid': 23, 'grid_code': 71001, 'Survey_ID': 73631, 'NAACC_ID': 71001, 'Lat': 42.34498, 'Long': -73.515309, 'Rd_Name': 'Braley-Gleason Rd', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 1.5, 'In_B': 1.5, 'HW': 3.3, 'Slope': 8.9, 'Length': 35, 'Out_Shape': 'Round Culvert', 'Out_A': 1.5, 'Out_B': 1.5, 'Crossing_T': 'Culvert', 'Comments': 'partially inaccessible but measurements estimated', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '112C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 622278.2765349196, 'y': 4689143.416399386}}),
#  Point(uid=70983, lat=4689083.416399388, lng=616558.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 24, 'pointid': 24, 'grid_code': 70983, 'Survey_ID': 73612, 'NAACC_ID': 70983, 'Lat': 42.345127, 'Long': -73.584883, 'Rd_Name': 'Route 9', 'Culv_Mat': 'Concrete', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 3, 'In_B': 2.9, 'HW': 2.5, 'Slope': 8.4, 'Length': 30, 'Out_Shape': 'Round Culvert', 'Out_A': 3, 'Out_B': 2.9, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '100C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 616558.2765349215, 'y': 4689083.416399388}}),
#  Point(uid=70992, lat=4688953.416399386, lng=625558.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 25, 'pointid': 25, 'grid_code': 70992, 'Survey_ID': 73622, 'NAACC_ID': 70992, 'Lat': 42.34256, 'Long': -73.47568, 'Rd_Name': 'Old Macedonia Road', 'Culv_Mat': 'Metal', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 1.5, 'In_B': 1.5, 'HW': 2.5, 'Slope': 4.7, 'Length': 30, 'Out_Shape': 'Round Culvert', 'Out_A': 1.5, 'Out_B': 1.5, 'Crossing_T': 'Multiple Culvert', 'Comments': 'perched high above stream bed. water flows down cascade of boulders', 'Flags': 2, 'Modeling_n': ' ', 'BarrierID': '104C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 625558.2765349206, 'y': 4688953.416399386}}),
#  Point(uid=70997, lat=4688793.416399388, lng=621548.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 26, 'pointid': 26, 'grid_code': 70997, 'Survey_ID': 73626, 'NAACC_ID': 70997, 'Lat': 42.341843, 'Long': -73.524254, 'Rd_Name': 'Ten Broek Road', 'Culv_Mat': 'Concrete', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 4, 'In_B': 4, 'HW': 2.5, 'Slope': -1, 'Length': 25, 'Out_Shape': 'Round Culvert', 'Out_A': 4, 'Out_B': 4, 'Crossing_T': 'Multiple Culvert', 'Comments': 'inlets inaccessible but measurements estimated by looking through outlet. could not get pictures or slope', 'Flags': 2, 'Modeling_n': ' ', 'BarrierID': '109C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 621548.2765349215, 'y': 4688793.416399388}}),
#  Point(uid=71431, lat=4688783.416399386, lng=606698.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 27, 'pointid': 27, 'grid_code': 71431, 'Survey_ID': 74033, 'NAACC_ID': 71431, 'Lat': 42.344006, 'Long': -73.704782, 'Rd_Name': 'Route 9H', 'Culv_Mat': 'Concrete', 'In_Type': 'Headwall', 'In_Shape': 'Round', 'In_A': 3, 'In_B': 3, 'HW': 3.5, 'Slope': 0.3, 'Length': 50, 'Out_Shape': 'Round Culvert', 'Out_A': 3, 'Out_B': 3, 'Crossing_T': 'Culvert', 'Comments': 'lots of fish swimming in and around structure', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '125C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 606698.2765349215, 'y': 4688783.416399386}}),
#  Point(uid=71649, lat=4688693.416399386, lng=609218.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 28, 'pointid': 28, 'grid_code': 71649, 'Survey_ID': 74258, 'NAACC_ID': 71649, 'Lat': 42.343016, 'Long': -73.67407, 'Rd_Name': 'Letter S Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 3, 'In_B': 3, 'HW': 1, 'Slope': 1, 'Length': 40, 'Out_Shape': 'Round Culvert', 'Out_A': 3, 'Out_B': 3, 'Crossing_T': 'Multiple Culvert', 'Comments': ' ', 'Flags': 2, 'Modeling_n': ' ', 'BarrierID': '143C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 609218.2765349206, 'y': 4688693.416399386}}),
#  Point(uid=71636, lat=4688613.416399388, lng=605458.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 29, 'pointid': 29, 'grid_code': 71636, 'Survey_ID': 74246, 'NAACC_ID': 71636, 'Lat': 42.342777, 'Long': -73.719741, 'Rd_Name': 'Falls Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 2.1, 'In_B': 1.7, 'HW': 3.6, 'Slope': 1, 'Length': 41.3, 'Out_Shape': 'Round Culvert', 'Out_A': 2, 'Out_B': 1.2, 'Crossing_T': 'Culvert', 'Comments': 'plastic pipe runs through structure and far upstream and downstream. Wall of phragmites downstream', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '133C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 605458.2765349215, 'y': 4688613.416399388}}),
#  Point(uid=70991, lat=4688513.416399386, lng=625718.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 30, 'pointid': 30, 'grid_code': 70991, 'Survey_ID': 73621, 'NAACC_ID': 70991, 'Lat': 42.338645, 'Long': -73.473794, 'Rd_Name': 'Beebe Forest Road', 'Culv_Mat': 'Metal', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 3, 'In_B': 3, 'HW': 1.2, 'Slope': 0.2, 'Length': 16, 'Out_Shape': 'Round Culvert', 'Out_A': 3, 'Out_B': 3, 'Crossing_T': 'Culvert', 'Comments': 'wetland on inlet side in between structure and pond. beautiful stream downstream. shaded area downstream', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '103C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 625718.2765349215, 'y': 4688513.416399386}}),
#  Point(uid=71635, lat=4688493.416399386, lng=605698.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 31, 'pointid': 31, 'grid_code': 71635, 'Survey_ID': 74245, 'NAACC_ID': 71635, 'Lat': 42.341576, 'Long': -73.716767, 'Rd_Name': 'Falls Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 2, 'In_B': 2.1, 'HW': 2.1, 'Slope': 1.7, 'Length': 40.5, 'Out_Shape': 'Round Culvert', 'Out_A': 2, 'Out_B': 2, 'Crossing_T': 'Culvert', 'Comments': 'dam upsream. dam owner said 10 years ago flooded 2 feet above road surface. town put rocks around outlet  to help with flooding. flows into pond downstream', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '132C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 605698.2765349215, 'y': 4688493.416399386}}),
#  Point(uid=71646, lat=4688323.416399386, lng=608528.2765349196, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 32, 'pointid': 32, 'grid_code': 71646, 'Survey_ID': 74254, 'NAACC_ID': 71646, 'Lat': 42.339716, 'Long': -73.682578, 'Rd_Name': 'Quinn Lane', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 1.5, 'In_B': 1.5, 'HW': 1.5, 'Slope': 0.3, 'Length': 30, 'Out_Shape': 'Round Culvert', 'Out_A': 1.5, 'Out_B': 1.5, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '140C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 608528.2765349196, 'y': 4688323.416399386}}),
#  Point(uid=71643, lat=4688323.416399386, lng=609168.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 33, 'pointid': 33, 'grid_code': 71643, 'Survey_ID': 74252, 'NAACC_ID': 71643, 'Lat': 42.339715, 'Long': -73.674737, 'Rd_Name': 'Quinn Lane', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 4, 'In_B': 4.2, 'HW': 1, 'Slope': 3.2, 'Length': 40, 'Out_Shape': 'Round Culvert', 'Out_A': 4, 'Out_B': 4.1, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '137C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 609168.2765349215, 'y': 4688323.416399386}}),
#  Point(uid=71436, lat=4688313.416399386, lng=609298.2765349224, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 34, 'pointid': 34, 'grid_code': 71436, 'Survey_ID': 74037, 'NAACC_ID': 71436, 'Lat': 42.339333, 'Long': -73.673037, 'Rd_Name': 'Quinn Lane', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 4, 'In_B': 4, 'HW': 1.5, 'Slope': 0.1, 'Length': 40, 'Out_Shape': 'Round Culvert', 'Out_A': 4, 'Out_B': 4, 'Crossing_T': 'Culvert', 'Comments': 'fish downstream', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '130C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 609298.2765349224, 'y': 4688313.416399386}}),
#  Point(uid=71052, lat=4688313.416399386, lng=611818.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 35, 'pointid': 35, 'grid_code': 71052, 'Survey_ID': 73681, 'NAACC_ID': 71052, 'Lat': 42.339136, 'Long': -73.64258, 'Rd_Name': 'Johnson Road', 'Culv_Mat': 'Concrete', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 2.5, 'In_B': 2.3, 'HW': 3, 'Slope': 8.1, 'Length': 29, 'Out_Shape': 'Round Culvert', 'Out_A': 2.3, 'Out_B': 1.7, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '118C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 611818.2765349206, 'y': 4688313.416399386}}),
#  Point(uid=73318, lat=4688313.416399386, lng=619208.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 36, 'pointid': 36, 'grid_code': 73318, 'Survey_ID': 76067, 'NAACC_ID': 73318, 'Lat': 42.338019, 'Long': -73.552777, 'Rd_Name': 'Beale Rd', 'Culv_Mat': 'Metal', 'In_Type': 'Projecting', 'In_Shape': 'Elliptical', 'In_A': 9, 'In_B': 6.6, 'HW': 2.5, 'Slope': 0.2, 'Length': 48.8, 'Out_Shape': 'Pipe Arch/Elliptical Culvert', 'Out_A': 9.3, 'Out_B': 6.5, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '215C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 619208.2765349215, 'y': 4688313.416399386}}),
#  Point(uid=71644, lat=4688303.416399386, lng=609008.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 37, 'pointid': 37, 'grid_code': 71644, 'Survey_ID': 74253, 'NAACC_ID': 71644, 'Lat': 42.339566, 'Long': -73.676662, 'Rd_Name': 'Quinn Lane', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 2, 'In_B': 2, 'HW': 1, 'Slope': 5.1, 'Length': 30, 'Out_Shape': 'Round Culvert', 'Out_A': 2, 'Out_B': 2, 'Crossing_T': 'Multiple Culvert', 'Comments': 'fish in front of inlet. cannot pass through culvert because perched and dry. inlets slightly wet but no flow', 'Flags': 2, 'Modeling_n': ' ', 'BarrierID': '138C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 609008.2765349206, 'y': 4688303.416399386}}),
#  Point(uid=71651, lat=4688263.416399386, lng=609348.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 38, 'pointid': 38, 'grid_code': 71651, 'Survey_ID': 74259, 'NAACC_ID': 71651, 'Lat': 42.338841, 'Long': -73.672524, 'Rd_Name': 'Letter S Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 4, 'In_B': 4, 'HW': 0.5, 'Slope': 5.1, 'Length': 30, 'Out_Shape': 'Round Culvert', 'Out_A': 4, 'Out_B': 4.2, 'Crossing_T': 'Culvert', 'Comments': 'fish upstream and downstream', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '145C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 609348.2765349206, 'y': 4688263.416399386}}),
#  Point(uid=70370, lat=4688233.4163993895, lng=619058.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 39, 'pointid': 39, 'grid_code': 70370, 'Survey_ID': 72975, 'NAACC_ID': 70370, 'Lat': 42.337217, 'Long': -73.554562, 'Rd_Name': 'Beale Road', 'Culv_Mat': 'Metal', 'In_Type': 'Projecting', 'In_Shape': 'Elliptical', 'In_A': 9.1, 'In_B': 6.5, 'HW': 2.5, 'Slope': 5.5, 'Length': 47, 'Out_Shape': 'Pipe Arch/Elliptical Culvert', 'Out_A': 9.1, 'Out_B': 6.5, 'Crossing_T': 'Culvert', 'Comments': 'concrete blocks to reduce erosion next to inlet. measured outlet by walking through. fish and crayfish seen at inlet. bedrock after outlet', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '61C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 619058.2765349206, 'y': 4688233.4163993895}}),
#  Point(uid=71050, lat=4688153.416399388, lng=611748.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 40, 'pointid': 40, 'grid_code': 71050, 'Survey_ID': 73679, 'NAACC_ID': 71050, 'Lat': 42.337815, 'Long': -73.64348, 'Rd_Name': 'County Route 22', 'Culv_Mat': 'Concrete', 'In_Type': 'Headwall', 'In_Shape': 'Round', 'In_A': 4, 'In_B': 4, 'HW': 3, 'Slope': -1, 'Length': 45, 'Out_Shape': 'Round Culvert', 'Out_A': 4, 'Out_B': 4, 'Crossing_T': 'Culvert', 'Comments': 'wetland on both sides. innaccessible for slope and pictures. steep slope and dense vegetation. crack across road over top of structure', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '116C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 611748.2765349215, 'y': 4688153.416399388}}),
#  Point(uid=71648, lat=4687813.416399386, lng=608288.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 41, 'pointid': 41, 'grid_code': 71648, 'Survey_ID': 74257, 'NAACC_ID': 71648, 'Lat': 42.335145, 'Long': -73.685362, 'Rd_Name': 'Laggett Road', 'Culv_Mat': 'Metal', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 11, 'In_B': 4.5, 'HW': 2.6, 'Slope': 1.7, 'Length': 18, 'Out_Shape': 'Box/Bridge with Abutments', 'Out_A': 11.5, 'Out_B': 4.5, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '142C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 608288.2765349215, 'y': 4687813.416399386}}),
#  Point(uid=70366, lat=4687803.416399386, lng=619928.2765349196, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 42, 'pointid': 42, 'grid_code': 70366, 'Survey_ID': 72971, 'NAACC_ID': 70366, 'Lat': 42.333384, 'Long': -73.544284, 'Rd_Name': 'Goodrich Lane', 'Culv_Mat': 'Metal', 'In_Type': 'Projecting', 'In_Shape': 'Arch', 'In_A': 3.2, 'In_B': 3.8, 'HW': 1.1, 'Slope': 2.5, 'Length': 20, 'Out_Shape': 'Open Bottom Arch Bridge/Culvert', 'Out_A': 3.5, 'Out_B': 3.5, 'Crossing_T': 'Culvert', 'Comments': 'frogs and small fish', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '57C19', 'BarrierID_': -61.0407239531, 'BarrierID1': 9751785204900000, 'geometry': {'x': 619928.2765349196, 'y': 4687803.416399386}}),
#  Point(uid=71432, lat=4687673.416399388, lng=606728.2765349224, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 43, 'pointid': 43, 'grid_code': 71432, 'Survey_ID': 74034, 'NAACC_ID': 71432, 'Lat': 42.333976, 'Long': -73.70442, 'Rd_Name': 'Route 9H', 'Culv_Mat': 'Concrete', 'In_Type': 'Headwall', 'In_Shape': 'Round', 'In_A': 1.7, 'In_B': 1.7, 'HW': 3.5, 'Slope': 3.2, 'Length': 50, 'Out_Shape': 'Round Culvert', 'Out_A': 1.5, 'Out_B': 1.5, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '126C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 606728.2765349224, 'y': 4687673.416399388}}),
#  Point(uid=70935, lat=4687663.416399386, lng=617668.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 44, 'pointid': 44, 'grid_code': 70935, 'Survey_ID': 73568, 'NAACC_ID': 70935, 'Lat': 42.332551, 'Long': -73.571729, 'Rd_Name': 'Angel Hill Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 1.5, 'In_B': 1.5, 'HW': 1.4, 'Slope': 1.9, 'Length': 45, 'Out_Shape': 'Round Culvert', 'Out_A': 1.5, 'Out_B': 1.5, 'Crossing_T': 'Culvert', 'Comments': 'driveway culvert upstream', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '68C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 617668.2765349215, 'y': 4687663.416399386}}),
#  Point(uid=70367, lat=4687473.416399388, lng=619588.2765349224, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 45, 'pointid': 45, 'grid_code': 70367, 'Survey_ID': 72972, 'NAACC_ID': 70367, 'Lat': 42.330365, 'Long': -73.548213, 'Rd_Name': 'Goodrich Lane', 'Culv_Mat': 'Metal', 'In_Type': 'Headwall', 'In_Shape': 'Arch', 'In_A': 6.3, 'In_B': 3.5, 'HW': 3.5, 'Slope': 3.5, 'Length': 22, 'Out_Shape': 'Open Bottom Arch Bridge/Culvert', 'Out_A': 7.1, 'Out_B': 3.6, 'Crossing_T': 'Culvert', 'Comments': 'fish in stream', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '58C19', 'BarrierID_': -61.0407239531, 'BarrierID1': 9751785204900000, 'geometry': {'x': 619588.2765349224, 'y': 4687473.416399388}}),
#  Point(uid=71054, lat=4687463.416399388, lng=611678.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 46, 'pointid': 46, 'grid_code': 71054, 'Survey_ID': 73683, 'NAACC_ID': 71054, 'Lat': 42.331455, 'Long': -73.644316, 'Rd_Name': 'Snyder Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 1.5, 'In_B': 1, 'HW': 2, 'Slope': 0.2, 'Length': 30, 'Out_Shape': 'Round Culvert', 'Out_A': 1.5, 'Out_B': 1.2, 'Crossing_T': 'Culvert', 'Comments': 'both ends filled in with silt', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '119C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 611678.2765349206, 'y': 4687463.416399388}}),
#  Point(uid=70149, lat=4687383.416399386, lng=619338.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 47, 'pointid': 47, 'grid_code': 70149, 'Survey_ID': 72734, 'NAACC_ID': 70149, 'Lat': 42.329423, 'Long': -73.551597, 'Rd_Name': 'Route 203', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 31.5, 'In_B': 10.5, 'HW': 3, 'Slope': 1.5, 'Length': 30, 'Out_Shape': 'Box/Bridge with Abutments', 'Out_A': 31.5, 'Out_B': 10.2, 'Crossing_T': 'Culvert', 'Comments': 'code 1040140. some deterioration on inlet and outlet support beams but not in the middle beams.  eroded stream banks shown in other photo 3', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '53C19', 'BarrierID_': -118.336503466, 'BarrierID1': 9751785204900000, 'geometry': {'x': 619338.2765349215, 'y': 4687383.416399386}}),
#  Point(uid=71634, lat=4687333.4163993895, lng=606578.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 48, 'pointid': 48, 'grid_code': 71634, 'Survey_ID': 74244, 'NAACC_ID': 71634, 'Lat': 42.331104, 'Long': -73.706349, 'Rd_Name': 'Falls Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 4, 'In_B': 4.1, 'HW': 1, 'Slope': 0.5, 'Length': 40.5, 'Out_Shape': 'Round Culvert', 'Out_A': 4, 'Out_B': 4, 'Crossing_T': 'Culvert', 'Comments': 'crayfish. very deep scour pool', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '131C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 606578.2765349215, 'y': 4687333.4163993895}}),
#  Point(uid=70974, lat=4687233.416399388, lng=614868.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 49, 'pointid': 49, 'grid_code': 70974, 'Survey_ID': 73601, 'NAACC_ID': 70974, 'Lat': 42.328976, 'Long': -73.60563, 'Rd_Name': 'Pach Road', 'Culv_Mat': 'Metal', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 3.9, 'In_B': 3.8, 'HW': 1, 'Slope': 0.2, 'Length': 30, 'Out_Shape': 'Round Culvert', 'Out_A': 4, 'Out_B': 4, 'Crossing_T': 'Culvert', 'Comments': 'stone dam just upstream. foot bridge over dam. impoundment appears to be under development. no vegetation surrounding impoundment shoreline. impoundment downstream with aeration and swans', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '93C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 614868.2765349215, 'y': 4687233.416399388}}),
#  Point(uid=70969, lat=4687153.416399386, lng=614448.2765349224, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 50, 'pointid': 50, 'grid_code': 70969, 'Survey_ID': 73598, 'NAACC_ID': 70969, 'Lat': 42.328028, 'Long': -73.61087, 'Rd_Name': 'Maple Avenue', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 1.5, 'In_B': 1.5, 'HW': 3, 'Slope': 1.6, 'Length': 40, 'Out_Shape': 'Round Culvert', 'Out_A': 1.5, 'Out_B': 1.5, 'Crossing_T': 'Multiple Culvert', 'Comments': ' ', 'Flags': 2, 'Modeling_n': ' ', 'BarrierID': '88C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 614448.2765349224, 'y': 4687153.416399386}}),
#  Point(uid=70971, lat=4687143.416399386, lng=614568.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 51, 'pointid': 51, 'grid_code': 70971, 'Survey_ID': 73599, 'NAACC_ID': 70971, 'Lat': 42.328097, 'Long': -73.609238, 'Rd_Name': 'Nelson Avenue', 'Culv_Mat': 'Fiberglass', 'In_Type': 'Projecting', 'In_Shape': 'Elliptical', 'In_A': 3.7, 'In_B': 2.4, 'HW': 2, 'Slope': 1.7, 'Length': 50, 'Out_Shape': 'Pipe Arch/Elliptical Culvert', 'Out_A': 3.7, 'Out_B': 2.4, 'Crossing_T': 'Multiple Culvert', 'Comments': 'drainage pipe just before inlet and just after outlet', 'Flags': 2, 'Modeling_n': ' ', 'BarrierID': '90C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 614568.2765349206, 'y': 4687143.416399386}}),
#  Point(uid=70999, lat=4687063.416399388, lng=614138.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 52, 'pointid': 52, 'grid_code': 70999, 'Survey_ID': 73628, 'NAACC_ID': 70999, 'Lat': 42.327591, 'Long': -73.614586, 'Rd_Name': 'Harlemville Road', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 10, 'In_B': 3.8, 'HW': 1.5, 'Slope': 1.2, 'Length': 25, 'Out_Shape': 'Box Culvert', 'Out_A': 10, 'Out_B': 3.6, 'Crossing_T': 'Culvert', 'Comments': 'natural bottom. slight build up of bottom sediment', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '111C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 614138.2765349206, 'y': 4687063.416399388}}),
#  Point(uid=71654, lat=4686813.416399388, lng=609778.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 53, 'pointid': 53, 'grid_code': 71654, 'Survey_ID': 74263, 'NAACC_ID': 71654, 'Lat': 42.325756, 'Long': -73.66774, 'Rd_Name': 'Talerico Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 3, 'In_B': 3, 'HW': 1.2, 'Slope': 3.8, 'Length': 40.5, 'Out_Shape': 'Round Culvert', 'Out_A': 3, 'Out_B': 3, 'Crossing_T': 'Culvert', 'Comments': 'Riprap on top of culvert and concrete ledge thing above culvert. Road crossing not paved but the road is paved', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '148C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 609778.2765349206, 'y': 4686813.416399388}}),
#  Point(uid=70938, lat=4686733.416399386, lng=616158.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 54, 'pointid': 54, 'grid_code': 70938, 'Survey_ID': 73570, 'NAACC_ID': 70938, 'Lat': 42.324138, 'Long': -73.590287, 'Rd_Name': 'Angel Hill Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 3.7, 'In_B': 3.9, 'HW': 1.5, 'Slope': 0.5, 'Length': 40, 'Out_Shape': 'Round Culvert', 'Out_A': 3.7, 'Out_B': 3.9, 'Crossing_T': 'Multiple Culvert', 'Comments': ' ', 'Flags': 2, 'Modeling_n': ' ', 'BarrierID': '71C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 616158.2765349206, 'y': 4686733.416399386}}),
#  Point(uid=71051, lat=4686643.416399388, lng=611358.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 55, 'pointid': 55, 'grid_code': 71051, 'Survey_ID': 73680, 'NAACC_ID': 71051, 'Lat': 42.324215, 'Long': -73.6484, 'Rd_Name': 'Habeck Road', 'Culv_Mat': 'Metal', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 4.3, 'In_B': 4.3, 'HW': 2, 'Slope': 3.2, 'Length': 31, 'Out_Shape': 'Round Culvert', 'Out_A': 4.4, 'Out_B': 4, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '117C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 611358.2765349206, 'y': 4686643.416399388}}),
#  Point(uid=71655, lat=4686583.416399388, lng=609808.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 56, 'pointid': 56, 'grid_code': 71655, 'Survey_ID': 74264, 'NAACC_ID': 71655, 'Lat': 42.323674, 'Long': -73.667316, 'Rd_Name': 'Talerico Road', 'Culv_Mat': 'Metal', 'In_Type': 'Headwall', 'In_Shape': 'Round', 'In_A': 3.9, 'In_B': 3.6, 'HW': 2.5, 'Slope': 7.1, 'Length': 32, 'Out_Shape': 'Round Culvert', 'Out_A': 3.8, 'Out_B': 3.6, 'Crossing_T': 'Culvert', 'Comments': 'Erosion next to inlet', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '149C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 609808.2765349215, 'y': 4686583.416399388}}),
#  Point(uid=70940, lat=4686513.416399386, lng=615728.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 57, 'pointid': 57, 'grid_code': 70940, 'Survey_ID': 73571, 'NAACC_ID': 70940, 'Lat': 42.322373, 'Long': -73.595637, 'Rd_Name': 'Angel Hill Road', 'Culv_Mat': 'Combination', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 10, 'In_B': 7, 'HW': 1.3, 'Slope': 1.1, 'Length': 20.5, 'Out_Shape': 'Box/Bridge with Abutments', 'Out_A': 10, 'Out_B': 6, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '73C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 615728.2765349206, 'y': 4686513.416399386}}),
#  Point(uid=70368, lat=4686473.416399386, lng=620408.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 58, 'pointid': 58, 'grid_code': 70368, 'Survey_ID': 72973, 'NAACC_ID': 70368, 'Lat': 42.3213, 'Long': -73.538645, 'Rd_Name': 'Chase Road', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 3.7, 'In_B': 4.1, 'HW': 2.8, 'Slope': 9.3, 'Length': 30, 'Out_Shape': 'Box Culvert', 'Out_A': -1, 'Out_B': -1, 'Crossing_T': 'Partially Inaccessible', 'Comments': 'outlet inaccessible due to steep slope', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '59C19', 'BarrierID_': -61.0407239531, 'BarrierID1': 9751785204900000, 'geometry': {'x': 620408.2765349206, 'y': 4686473.416399386}}),
#  Point(uid=70364, lat=4686413.416399388, lng=620338.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 59, 'pointid': 59, 'grid_code': 70364, 'Survey_ID': 72969, 'NAACC_ID': 70364, 'Lat': 42.32078, 'Long': -73.539455, 'Rd_Name': 'Route 203', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 3.6, 'In_B': 4.5, 'HW': 4.7, 'Slope': 12.1, 'Length': 45, 'Out_Shape': 'Box Culvert', 'Out_A': 3.2, 'Out_B': 4.5, 'Crossing_T': 'Culvert', 'Comments': 'wingwalls on both side falling apart. drain pipe nearby uphill of outlet', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '55C19', 'BarrierID_': -61.0407239531, 'BarrierID1': 9751785204900000, 'geometry': {'x': 620338.2765349215, 'y': 4686413.416399388}}),
# ...
#  Point(uid=69949, lat=4663443.416399386, lng=603638.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 178, 'pointid': 178, 'grid_code': 69949, 'Survey_ID': 72482, 'NAACC_ID': 69949, 'Lat': 42.116033, 'Long': -73.746274, 'Rd_Name': 'Taghkanic Rd', 'Culv_Mat': 'Concrete', 'In_Type': 'Headwall', 'In_Shape': 'Box', 'In_A': 8.2, 'In_B': 2.9, 'HW': 2.9, 'Slope': 1, 'Length': 31.5, 'Out_Shape': 'Pipe Arch/Elliptical Culvert', 'Out_A': 8.5, 'Out_B': 3.4, 'Crossing_T': 'Culvert', 'Comments': 'Concrete at outlet cracking. Nearby resident mentioned that during flood events the water barely stays in the culvert and the outlet side has been sinking over the years', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '38C19', 'BarrierID_': -175.632282979, 'BarrierID1': 9751785204900000, 'geometry': {'x': 603638.2765349206, 'y': 4663443.416399386}}),
#  Point(uid=69952, lat=4663393.416399388, lng=606028.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 179, 'pointid': 179, 'grid_code': 69952, 'Survey_ID': 72485, 'NAACC_ID': 69952, 'Lat': 42.115413, 'Long': -73.717501, 'Rd_Name': 'County Route 15', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 6.2, 'In_B': 4, 'HW': 0, 'Slope': -1, 'Length': 33, 'Out_Shape': 'Box/Bridge with Abutments', 'Out_A': 6.1, 'Out_B': 4.5, 'Crossing_T': 'Bridge', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '39C19', 'BarrierID_': -175.632282979, 'BarrierID1': 9751785204900000, 'geometry': {'x': 606028.2765349215, 'y': 4663393.416399388}}),
#  Point(uid=71728, lat=4662993.416399386, lng=612958.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 180, 'pointid': 180, 'grid_code': 71728, 'Survey_ID': 74379, 'NAACC_ID': 71728, 'Lat': 42.110985, 'Long': -73.633685, 'Rd_Name': 'Crow Hill Road', 'Culv_Mat': 'Concrete', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 1.3, 'In_B': 1.3, 'HW': 1.7, 'Slope': 3.1, 'Length': 20.6, 'Out_Shape': 'Round Culvert', 'Out_A': 1.3, 'Out_B': 1.3, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '164C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 612958.2765349215, 'y': 4662993.416399386}}),
#  Point(uid=71928, lat=4662583.416399386, lng=603258.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 181, 'pointid': 181, 'grid_code': 71928, 'Survey_ID': 74581, 'NAACC_ID': 71928, 'Lat': 42.108644, 'Long': -73.750949, 'Rd_Name': 'unnamed driveway off Taghkanic Rd', 'Culv_Mat': 'Metal', 'In_Type': 'Other', 'In_Shape': 'Round', 'In_A': 2.5, 'In_B': 2.5, 'HW': 3, 'Slope': 2.1, 'Length': 23, 'Out_Shape': 'Round Culvert', 'Out_A': 2.5, 'Out_B': 2.5, 'Crossing_T': 'Culvert', 'Comments': 'bankfull estimated due to low swamp area upstream', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '168C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 603258.2765349215, 'y': 4662583.416399386}}),
#  Point(uid=71683, lat=4662543.416399386, lng=611888.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 182, 'pointid': 182, 'grid_code': 71683, 'Survey_ID': 74329, 'NAACC_ID': 71683, 'Lat': 42.10698, 'Long': -73.646541, 'Rd_Name': 'New Forge Rd', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 1.3, 'In_B': 1.3, 'HW': 1.5, 'Slope': 4.2, 'Length': 35.1, 'Out_Shape': 'Round Culvert', 'Out_A': 1.3, 'Out_B': 1.3, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '153C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 611888.2765349206, 'y': 4662543.416399386}}),
#  Point(uid=69958, lat=4662513.4163993895, lng=603428.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 183, 'pointid': 183, 'grid_code': 69958, 'Survey_ID': 72490, 'NAACC_ID': 69958, 'Lat': 42.107891, 'Long': -73.748731, 'Rd_Name': 'Taghkanic Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 2.1, 'In_B': 1.5, 'HW': 5.74, 'Slope': 1.7, 'Length': 52, 'Out_Shape': 'Round Culvert', 'Out_A': 2, 'Out_B': 2, 'Crossing_T': 'Culvert', 'Comments': 'Bankfull taken with one measurement due to excessive vegetative growth upstream.', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '40C19', 'BarrierID_': -175.632282979, 'BarrierID1': 9751785204900000, 'geometry': {'x': 603428.2765349206, 'y': 4662513.4163993895}}),
#  Point(uid=69383, lat=4662443.416399388, lng=606058.2765349224, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 184, 'pointid': 184, 'grid_code': 69383, 'Survey_ID': 71786, 'NAACC_ID': 69383, 'Lat': 42.106798, 'Long': -73.71735, 'Rd_Name': 'Taconic State parkway Northbound', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall', 'In_Shape': 'Round', 'In_A': 4, 'In_B': 4, 'HW': 3.12, 'Slope': 8.4, 'Length': 84.9, 'Out_Shape': 'Round Culvert', 'Out_A': 4, 'Out_B': 4, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '23C19', 'BarrierID_': 69.7761579946, 'BarrierID1': 9751785204900000, 'geometry': {'x': 606058.2765349224, 'y': 4662443.416399388}}),
#  Point(uid=71924, lat=4662383.416399386, lng=606018.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 185, 'pointid': 185, 'grid_code': 71924, 'Survey_ID': 74573, 'NAACC_ID': 71924, 'Lat': 42.106297, 'Long': -73.717867, 'Rd_Name': 'Taconic St Parkway S', 'Culv_Mat': 'Concrete', 'In_Type': 'Headwall', 'In_Shape': 'Round', 'In_A': 3.9, 'In_B': 4, 'HW': 3.5, 'Slope': 3.5, 'Length': 76.5, 'Out_Shape': 'Round Culvert', 'Out_A': 4, 'Out_B': 4, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '165C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 606018.2765349215, 'y': 4662383.416399386}}),
#  Point(uid=69959, lat=4662303.4163993895, lng=602488.2765349224, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 186, 'pointid': 186, 'grid_code': 69959, 'Survey_ID': 72491, 'NAACC_ID': 69959, 'Lat': 42.106097, 'Long': -73.76016, 'Rd_Name': 'Dranbauer road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 2, 'In_B': 2, 'HW': 2.57, 'Slope': 4.6, 'Length': 53.7, 'Out_Shape': 'Round Culvert', 'Out_A': 2.2, 'Out_B': 2, 'Crossing_T': 'Culvert', 'Comments': 'Stream forks off just upstream, only took one bankfull measurement.', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '41C19', 'BarrierID_': -175.632282979, 'BarrierID1': 9751785204900000, 'geometry': {'x': 602488.2765349224, 'y': 4662303.4163993895}}),
#  Point(uid=69960, lat=4662253.416399388, lng=604628.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 187, 'pointid': 187, 'grid_code': 69960, 'Survey_ID': 72493, 'NAACC_ID': 69960, 'Lat': 42.105588, 'Long': -73.734574, 'Rd_Name': 'Sapok Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 2.5, 'In_B': 2.4, 'HW': 1.02, 'Slope': 0.4, 'Length': 40.2, 'Out_Shape': 'Round Culvert', 'Out_A': 2.6, 'Out_B': 2.5, 'Crossing_T': 'Culvert', 'Comments': 'At the outlet the pipe is corroded at the bottom.', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '42C19', 'BarrierID_': -175.632282979, 'BarrierID1': 9751785204900000, 'geometry': {'x': 604628.2765349206, 'y': 4662253.416399388}}),
#  Point(uid=64678, lat=4661943.416399386, lng=616598.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 188, 'pointid': 188, 'grid_code': 64678, 'Survey_ID': 66756, 'NAACC_ID': 64678, 'Lat': 42.101002, 'Long': -73.589809, 'Rd_Name': 'County Route 7', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 5.8, 'In_B': 3, 'HW': 2.5, 'Slope': 0.1, 'Length': 43, 'Out_Shape': 'Box Culvert', 'Out_A': 5.4, 'Out_B': 3.4, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '8C19', 'BarrierID_': 12.4803784815, 'BarrierID1': 9751785204900000, 'geometry': {'x': 616598.2765349206, 'y': 4661943.416399386}}),
#  Point(uid=71926, lat=4661533.416399388, lng=605858.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 189, 'pointid': 189, 'grid_code': 71926, 'Survey_ID': 74578, 'NAACC_ID': 71926, 'Lat': 42.098546, 'Long': -73.719828, 'Rd_Name': 'Route 15', 'Culv_Mat': 'Plastic', 'In_Type': 'Mitered to Slope', 'In_Shape': 'Round', 'In_A': 1.4, 'In_B': 1.2, 'HW': 3.5, 'Slope': 2.1, 'Length': 38, 'Out_Shape': 'Round Culvert', 'Out_A': 1.3, 'Out_B': 1.3, 'Crossing_T': 'Culvert', 'Comments': 'Possibly road drainage, could not find upstream channel, it was flowing heavily probably because we got a lot of rain last night,', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '167C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 605858.2765349206, 'y': 4661533.416399388}}),
#  Point(uid=71682, lat=4661523.416399388, lng=609958.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 190, 'pointid': 190, 'grid_code': 71682, 'Survey_ID': 74327, 'NAACC_ID': 71682, 'Lat': 42.098009, 'Long': -73.670102, 'Rd_Name': 'Old Forge Road Spur', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 2, 'In_B': 2, 'HW': 1, 'Slope': 5.2, 'Length': 39.8, 'Out_Shape': 'Round Culvert', 'Out_A': 21, 'Out_B': 2, 'Crossing_T': 'Culvert', 'Comments': 'Appears to be draining a narrow roadside ditch, into the stream across the road, so probably road drainage, no obvious flowline. There is another pipe approximately 1.5 ft from the inlet, we did not assess because appeared to be an outfall draining from', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '152C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 609958.2765349215, 'y': 4661523.416399388}}),
#  Point(uid=64677, lat=4661163.4163993895, lng=614268.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 191, 'pointid': 191, 'grid_code': 64677, 'Survey_ID': 66755, 'NAACC_ID': 64677, 'Lat': 42.094236, 'Long': -73.617978, 'Rd_Name': 'Thompkins Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 1.3, 'In_B': 1.4, 'HW': 1.3, 'Slope': -1, 'Length': 36.7, 'Out_Shape': 'Round Culvert', 'Out_A': 1.3, 'Out_B': 1.3, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '7C19', 'BarrierID_': 12.4803784815, 'BarrierID1': 9751785204900000, 'geometry': {'x': 614268.2765349206, 'y': 4661163.4163993895}}),
#  Point(uid=64676, lat=4660743.416399384, lng=616218.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 192, 'pointid': 192, 'grid_code': 64676, 'Survey_ID': 66754, 'NAACC_ID': 64676, 'Lat': 42.090356, 'Long': -73.594754, 'Rd_Name': 'Bettman Lane', 'Culv_Mat': 'Metal', 'In_Type': 'Headwall', 'In_Shape': 'Round', 'In_A': 3.1, 'In_B': 2.8, 'HW': 2.7, 'Slope': 0.4, 'Length': 41, 'Out_Shape': 'Round Culvert', 'Out_A': 3, 'Out_B': 3, 'Crossing_T': 'Culvert', 'Comments': 'Passerby noted that this is a private road', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '6C19', 'BarrierID_': -44.8154010316, 'BarrierID1': 9751785204900000, 'geometry': {'x': 616218.2765349215, 'y': 4660743.416399384}}),
#  Point(uid=64675, lat=4660573.416399386, lng=616218.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 193, 'pointid': 193, 'grid_code': 64675, 'Survey_ID': 66753, 'NAACC_ID': 64675, 'Lat': 42.088749, 'Long': -73.594683, 'Rd_Name': 'Driveway', 'Culv_Mat': 'Metal', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 2.5, 'In_B': 2, 'HW': 0.3, 'Slope': 1.1, 'Length': 48.2, 'Out_Shape': 'Round Culvert', 'Out_A': 2.5, 'Out_B': 2.5, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '5C19', 'BarrierID_': -44.8154010316, 'BarrierID1': 9751785204900000, 'geometry': {'x': 616218.2765349215, 'y': 4660573.416399386}}),
#  Point(uid=64674, lat=4660573.416399386, lng=616308.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 194, 'pointid': 194, 'grid_code': 64674, 'Survey_ID': 66752, 'NAACC_ID': 64674, 'Lat': 42.088467, 'Long': -73.593666, 'Rd_Name': 'County Route 7', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 1.5, 'In_B': 1.5, 'HW': 1.4, 'Slope': 2.6, 'Length': 45, 'Out_Shape': 'Round Culvert', 'Out_A': 1.3, 'Out_B': 1.3, 'Crossing_T': 'Culvert', 'Comments': 'Storm drain', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '4C19', 'BarrierID_': -44.8154010316, 'BarrierID1': 9751785204900000, 'geometry': {'x': 616308.2765349215, 'y': 4660573.416399386}}),
#  Point(uid=64673, lat=4660293.416399384, lng=616218.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 195, 'pointid': 195, 'grid_code': 64673, 'Survey_ID': 66751, 'NAACC_ID': 64673, 'Lat': 42.08623, 'Long': -73.594912, 'Rd_Name': 'County Route 7', 'Culv_Mat': 'Concrete', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 4, 'In_B': 4, 'HW': 4, 'Slope': 2.4, 'Length': 101, 'Out_Shape': 'Round Culvert', 'Out_A': 4, 'Out_B': 3.2, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '3C19', 'BarrierID_': -44.8154010316, 'BarrierID1': 9751785204900000, 'geometry': {'x': 616218.2765349215, 'y': 4660293.416399384}}),
#  Point(uid=64672, lat=4660103.416399386, lng=614088.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 196, 'pointid': 196, 'grid_code': 64672, 'Survey_ID': 66750, 'NAACC_ID': 64672, 'Lat': 42.084814, 'Long': -73.620643, 'Rd_Name': 'Banor Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 3, 'In_B': 3, 'HW': 1.2, 'Slope': 3.1, 'Length': 31, 'Out_Shape': 'Round Culvert', 'Out_A': 3, 'Out_B': 3, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '2C19', 'BarrierID_': -44.8154010316, 'BarrierID1': 9751785204900000, 'geometry': {'x': 614088.2765349215, 'y': 4660103.416399386}})]

# %% [markdown]
# ### Get a subset of inlets for testing purposes

# %%
# some_inlets = SelectLayerByAttribute(
#     in_layer_or_view=fslyr,
#     selection_type='NEW_SELECTION',
#     where_clause="Survey_ID < 67000"
# )
# inlet_count = int(GetCount(some_inlets).getOutput(0))
# print(inlet_count)

some_inlets = points[0:10]

# %% [markdown]
# ## Read in the rainfall rasters
#
# from the rainfall config `json` file.

# %%
with open(rainfall_rasters_config) as fp:
    rainfall_rasters = json.load(fp)
    
rainfall_rasters = [
    {
        'path': Path(rainfall_rasters['root']) / r['path'],
        'freq': r['freq']
    }
    for r in rainfall_rasters['rasters'] if r['ext'] == ".asc"
]

rainfall_rasters
# Out:
# [{'path': WindowsPath('D:/Dropbox (CivicMapper)/Projects/202004-02 Cornell Modeling/3 - Production/tool outputs/c19 tests/noaa_rainfall/ne1yr24ha.asc'),
#   'freq': 1},
#  {'path': WindowsPath('D:/Dropbox (CivicMapper)/Projects/202004-02 Cornell Modeling/3 - Production/tool outputs/c19 tests/noaa_rainfall/ne2yr24ha.asc'),
#   'freq': 2},
#  {'path': WindowsPath('D:/Dropbox (CivicMapper)/Projects/202004-02 Cornell Modeling/3 - Production/tool outputs/c19 tests/noaa_rainfall/ne5yr24ha.asc'),
#   'freq': 5},
#  {'path': WindowsPath('D:/Dropbox (CivicMapper)/Projects/202004-02 Cornell Modeling/3 - Production/tool outputs/c19 tests/noaa_rainfall/ne10yr24ha.asc'),
#   'freq': 10},
#  {'path': WindowsPath('D:/Dropbox (CivicMapper)/Projects/202004-02 Cornell Modeling/3 - Production/tool outputs/c19 tests/noaa_rainfall/ne25yr24ha.asc'),
#   'freq': 25},
#  {'path': WindowsPath('D:/Dropbox (CivicMapper)/Projects/202004-02 Cornell Modeling/3 - Production/tool outputs/c19 tests/noaa_rainfall/ne50yr24ha.asc'),
#   'freq': 50},
#  {'path': WindowsPath('D:/Dropbox (CivicMapper)/Projects/202004-02 Cornell Modeling/3 - Production/tool outputs/c19 tests/noaa_rainfall/ne100yr24ha.asc'),
#   'freq': 100},
#  {'path': WindowsPath('D:/Dropbox (CivicMapper)/Projects/202004-02 Cornell Modeling/3 - Production/tool outputs/c19 tests/noaa_rainfall/ne200yr24ha.asc'),
#   'freq': 200},
#  {'path': WindowsPath('D:/Dropbox (CivicMapper)/Projects/202004-02 Cornell Modeling/3 - Production/tool outputs/c19 tests/noaa_rainfall/ne500yr24ha.asc'),
#   'freq': 500},
#  {'path': WindowsPath('D:/Dropbox (CivicMapper)/Projects/202004-02 Cornell Modeling/3 - Production/tool outputs/c19 tests/noaa_rainfall/ne1000yr24ha.asc'),
#   'freq': 1000}]

# %% [markdown]
# ## Iterative Delineation and Analysis:

# %%
sheds = []

# with SearchCursor(some_inlets, [pour_point_field]) as sc:
#     for inlet in tqdm(sc, total=inlet_count):

for point in points[0:10]:
    
    print("--------------------------------")
    print("inlet", point.uid)
    
    print("deriving FeatureSet")
    feature_set_for_point = create_geodata_from_points([point], as_dict=False)    
    print(feature_set_for_point, feature_set_for_point.JSON)

#         selected_inlet = SelectLayerByAttribute(
#             in_layer_or_view=some_inlets,
#             selection_type='NEW_SELECTION',
#             where_clause="{0}= {1}".format(pour_point_field, inlet[0])
#         )

#     selected_inlet = feature_set_for_point

    # we can get a tabular look at what's in the layer like this:
#         fs = json.loads(FeatureSet(selected_inlet).JSON)
#         ft = etl.fromdicts(fs['features']).unpackdict('attributes').unpackdict('geometry')
#         etl.vis.displayall(ft)

    with EnvManager(
        snapRaster=str(fd),
        cellSize=str(fd)
    ):
        # delineate one watershed
        print('delineating')
        one_shed = Watershed(
            in_flow_direction_raster=str(fd),
            in_pour_point_data=feature_set_for_point,
            #pour_point_field=pour_point_field
        )

        #one_shed.save(str(test_results_dir / "catchment_{}.tif".format(inlet[0])))
        one_shed_path = r"in_memory/catchment_{}.tif".format(point.uid)
        one_shed.save(one_shed_path)

    print(one_shed, type(one_shed))


    # -------------------------------------------------
    # ANALYSIS


    ## ---------------------------
    # calculate area of catchment

    #ZonalGeometryAsTable(catchment_areas,"Value","output_table") # crashes like a mfer
    #cp = self.so("catchmentpolygons","timestamp","fgdb")
    cp = CreateUniqueName(
        "basin{0}".format(point.uid),
        "in_memory"
    )
    print(cp)
    #RasterToPolygon copies our ids from self.raster_field into "gridcode"
    if out_catchment_polygons_simplify:
        simplify = "SIMPLIFY"
    else:
        simplify = "NO_SIMPLIFY"

    RasterToPolygon(one_shed, cp, simplify)

    # Dissolve the converted polygons, since some of the raster zones may have corner-corner links
    #cpd = self.so("catchmentpolygonsdissolved","timestamp","fgdb")
    cpd = CreateUniqueName(
        "basin{0}_dissolved".format(point.uid),
        "in_memory"
    )

    Dissolve(
        in_features=cp,
        out_feature_class=cpd,
        dissolve_field="gridcode",
        multi_part="MULTI_PART"
    )

    # get the area for each record, and push into results object
    total_area = None
    areas = []
    with SearchCursor(cpd,["gridcode","SHAPE@AREA"]) as c:
        for r in c:
            this_id = r[0]
            this_area = r[1]# * area_conv_factor
            areas.append(this_area)

    total_area = sum(areas)
    print("area:", total_area)


    ## ---------------------------
    # calculate flow length

    fl_max = None

    with EnvManager(
        snapRaster=str(fd),
        cellSize=str(fd)
    ):

        # clip the flow direction raster to the catchment area (zone value)
        clipped_flowdir = SetNull(IsNull(one_shed), str(fd))
        # calculate flow length
        flow_len = FlowLength(clipped_flowdir, "UPSTREAM")
        # determine maximum flow length
        fl_max = flow_len.maximum
        #TODO: convert length to ? using leng_conv_factor (detected from the flow direction raster)
        #fl_max = fl_max * leng_conv_factor

    print("flow length:", fl_max)


    ## ---------------------------
    # calculate average curve number

    avg_cn = None

    table_cn_avg = CreateUniqueName(
        "basin{0}_cn_avg".format(point.uid),
        "in_memory"
    )
    with EnvManager(
        cellSizeProjectionMethod="PRESERVE_RESOLUTION",
        extent="MINOF",
        cellSize=one_shed
    ):        
        ZonalStatisticsAsTable(
            one_shed, 
            'Value', 
            Raster(str(cn)),
            table_cn_avg, 
            "DATA",
            "MEAN"
        )
        cn_stats = json.loads(RecordSet(table_cn_avg).JSON)

        if len(cn_stats['features']) > 0:
            means = [f['attributes']['MEAN'] for f in cn_stats['features']]
            avg_cn = mean(means)

        print("Average Curve Number:", avg_cn)



    ## ---------------------------
    # calculate average slope

    avg_slope = None

    table_slope_avg = CreateUniqueName(
        "basin{0}_slope_avg".format(point.uid),
        "in_memory"
    )

    with EnvManager(
        cellSizeProjectionMethod="PRESERVE_RESOLUTION",
        extent="MINOF",
        cellSize=one_shed
    ):        
        ZonalStatisticsAsTable(
            one_shed, 
            'Value', 
            Raster(str(slope)),
            table_slope_avg, 
            "DATA",
            "MEAN"
        )

        slope_stats = json.loads(RecordSet(table_slope_avg).JSON)
        if len(slope_stats['features']) > 0:
            means = [f['attributes']['MEAN'] for f in slope_stats['features']]
            avg_slope = mean(means)
        print("Average Slope:", avg_slope)


    ## ---------------------------
    # calculate average rainfall for each storm period

    rainfalls = []

    print('calculating rainfall average for')
    for rr in rainfall_rasters:

        avg_rainfall = None

        #table_rainfall_avg = self.so("rainfall_avg", p, "fgdb")
        table_rainfall_avg = CreateUniqueName(
            "basin{0}_rainfall_avg{1}".format(point.uid, rr['freq']),
            "in_memory"
        )

        with EnvManager(
            cellSizeProjectionMethod="PRESERVE_RESOLUTION",
            extent="MINOF",
            cellSize=one_shed
        ):
            ZonalStatisticsAsTable(
                one_shed,
                'Value',
                Raster(str(rr['path'])),
                table_rainfall_avg,
                "DATA",
                "MEAN"
            )

        rainfall_stats = json.loads(RecordSet(table_rainfall_avg).JSON)

        if len(rainfall_stats['features']) > 0:
            means = [f['attributes']['MEAN'] for f in rainfall_stats['features']]
            avg_rainfall = mean(means) * 25.4 / 1000

        print(rr['freq'], "year event:", avg_rainfall)
        rainfalls.append(Rainfall(rr['freq'], '24hr', avg_rainfall))

    shed = Shed(
        uid=point.uid,
        area_sqkm=total_area,
        avg_slope_pct=avg_slope,
        avg_cn=avg_cn,
        max_fl=fl_max,
        rainfall=rainfalls,
        shed_polygon_filepath = cpd,
        shed_raster_filepath = one_shed_path            
    )
    point.shed = shed
    sheds.append(shed)
# Out:
# --------------------------------
# inlet 70978
# deriving FeatureSet
# [26918]
# <geoprocessing spatial reference object object at 0x0000016FBA5FEE70>
# [Point(uid=70978, lat=4690423.416399388, lng=618918.2765349224, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 1, 'pointid': 1, 'grid_code': 70978, 'Survey_ID': 73607, 'NAACC_ID': 70978, 'Lat': 42.35717, 'Long': -73.556041, 'Rd_Name': 'Raup Road', 'Culv_Mat': 'Metal', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 4.9, 'In_B': 4.8, 'HW': 2, 'Slope': 2.8, 'Length': 26, 'Out_Shape': 'Round Culvert', 'Out_A': 5.2, 'Out_B': 5.4, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '96C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 618918.2765349224, 'y': 4690423.416399388}})]
# <geoprocessing record set object object at 0x0000016FBA721F50> {"displayFieldName":"","fieldAliases":{"OID":"OID","uid":"uid","group_id":"group_id"},"geometryType":"esriGeometryPoint","spatialReference":{"wkid":26918,"latestWkid":26918},"fields":[{"name":"OID","type":"esriFieldTypeOID","alias":"OID"},{"name":"uid","type":"esriFieldTypeString","alias":"uid"},{"name":"group_id","type":"esriFieldTypeString","alias":"group_id"}],"features":[{"attributes":{"OID":1,"uid":"70978","group_id":null},"geometry":{"x":618918.27649999969,"y":4690423.4164000005}}]}
# delineating
# in_memory\catchment_70978.tif <class 'arcpy.sa.Raster.Raster'>
# in_memory\basin70978
# area: 3198.260236505569
# flow length: 88.260292053223
# Average Curve Number: 77.75
# Average Slope: 16.102196872234344
# calculating rainfall average for
# 1 year event: 59.74079999999999
# 2 year event: 74.1172
# 5 year event: 97.6122
# 10 year event: 117.1194
# 25 year event: 143.9672
# 50 year event: 163.80459999999997
# 100 year event: 185.3438
# 200 year event: 211.63279999999997
# 500 year event: 251.94259999999997
# 1000 year event: 286.61359999999996
# --------------------------------
# inlet 71056
# deriving FeatureSet
# [26918]
# <geoprocessing spatial reference object object at 0x0000016FBA721250>
# [Point(uid=71056, lat=4690193.416399388, lng=610968.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 2, 'pointid': 2, 'grid_code': 71056, 'Survey_ID': 73685, 'NAACC_ID': 71056, 'Lat': 42.356053, 'Long': -73.652552, 'Rd_Name': 'Mile Hill Road', 'Culv_Mat': 'Concrete', 'In_Type': 'Mitered to Slope', 'In_Shape': 'Round', 'In_A': 1.5, 'In_B': 1.3, 'HW': 5, 'Slope': -1, 'Length': 42, 'Out_Shape': 'Round Culvert', 'Out_A': 1.5, 'Out_B': 1.5, 'Crossing_T': 'Culvert', 'Comments': 'headwall on outlet side. large pond downstream', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '121C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 610968.2765349215, 'y': 4690193.416399388}})]
# <geoprocessing record set object object at 0x0000016FBA7211F0> {"displayFieldName":"","fieldAliases":{"OID":"OID","uid":"uid","group_id":"group_id"},"geometryType":"esriGeometryPoint","spatialReference":{"wkid":26918,"latestWkid":26918},"fields":[{"name":"OID","type":"esriFieldTypeOID","alias":"OID"},{"name":"uid","type":"esriFieldTypeString","alias":"uid"},{"name":"group_id","type":"esriFieldTypeString","alias":"group_id"}],"features":[{"attributes":{"OID":1,"uid":"71056","group_id":null},"geometry":{"x":610968.27649999969,"y":4690193.4164000005}}]}
# delineating
# in_memory\catchment_71056.tif <class 'arcpy.sa.Raster.Raster'>
# in_memory\basin71056
# area: 1599.1361166362162
# flow length: 48.271156311035
# Average Curve Number: 74
# Average Slope: 8.87437504529953
# calculating rainfall average for
# 1 year event: 56.6928
# 2 year event: 69.85
# 5 year event: 91.3384
# 10 year event: 109.1692
# 25 year event: 133.7056
# 50 year event: 151.892
# 100 year event: 171.55159999999998
# 200 year event: 195.199
# 500 year event: 231.013
# 1000 year event: 261.59459999999996
# --------------------------------
# inlet 70979
# deriving FeatureSet
# [26918]
# <geoprocessing spatial reference object object at 0x0000016FBA721230>
# [Point(uid=70979, lat=4690163.416399388, lng=618868.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 3, 'pointid': 3, 'grid_code': 70979, 'Survey_ID': 73608, 'NAACC_ID': 70979, 'Lat': 42.354772, 'Long': -73.556639, 'Rd_Name': 'Red Rock Road', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 6, 'In_B': 5.1, 'HW': 7, 'Slope': 6.8, 'Length': 35, 'Out_Shape': 'Box Culvert', 'Out_A': 5.9, 'Out_B': 5, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '97C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 618868.2765349215, 'y': 4690163.416399388}})]
# <geoprocessing record set object object at 0x0000016FBA721C30> {"displayFieldName":"","fieldAliases":{"OID":"OID","uid":"uid","group_id":"group_id"},"geometryType":"esriGeometryPoint","spatialReference":{"wkid":26918,"latestWkid":26918},"fields":[{"name":"OID","type":"esriFieldTypeOID","alias":"OID"},{"name":"uid","type":"esriFieldTypeString","alias":"uid"},{"name":"group_id","type":"esriFieldTypeString","alias":"group_id"}],"features":[{"attributes":{"OID":1,"uid":"70979","group_id":null},"geometry":{"x":618868.27649999969,"y":4690163.4164000005}}]}
# delineating
# in_memory\catchment_70979.tif <class 'arcpy.sa.Raster.Raster'>
# in_memory\basin70979
# area: 960278.1968657345
# flow length: 2084.5324707031
# Average Curve Number: 76.34970857618652
# Average Slope: 12.437299312749175
# calculating rainfall average for
# 1 year event: 59.829784596169866
# 2 year event: 74.23308617818483
# 5 year event: 97.77590416319732
# 10 year event: 117.31586402997502
# 25 year event: 144.20422789342214
# 50 year event: 164.06771523730225
# 100 year event: 185.65268176519564
# 200 year event: 212.02942914238133
# 500 year event: 252.50813597002494
# 1000 year event: 287.33972064945874
# --------------------------------
# inlet 73324
# deriving FeatureSet
# [26918]
# <geoprocessing spatial reference object object at 0x0000016FBA721750>
# [Point(uid=73324, lat=4690093.416399386, lng=618848.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 4, 'pointid': 4, 'grid_code': 73324, 'Survey_ID': 76071, 'NAACC_ID': 73324, 'Lat': 42.354158, 'Long': -73.556776, 'Rd_Name': 'Old road', 'Culv_Mat': 'Combination', 'In_Type': 'Wingwall', 'In_Shape': 'Box', 'In_A': 19.9, 'In_B': 7.1, 'HW': 0, 'Slope': -1, 'Length': 20.4, 'Out_Shape': 'Box/Bridge with Abutments', 'Out_A': 20, 'Out_B': 7.2, 'Crossing_T': 'Bridge', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '220C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 618848.2765349206, 'y': 4690093.416399386}})]
# <geoprocessing record set object object at 0x0000016FBA721CB0> {"displayFieldName":"","fieldAliases":{"OID":"OID","uid":"uid","group_id":"group_id"},"geometryType":"esriGeometryPoint","spatialReference":{"wkid":26918,"latestWkid":26918},"fields":[{"name":"OID","type":"esriFieldTypeOID","alias":"OID"},{"name":"uid","type":"esriFieldTypeString","alias":"uid"},{"name":"group_id","type":"esriFieldTypeString","alias":"group_id"}],"features":[{"attributes":{"OID":1,"uid":"73324","group_id":null},"geometry":{"x":618848.27649999969,"y":4690093.4164000005}}]}
# delineating
# in_memory\catchment_73324.tif <class 'arcpy.sa.Raster.Raster'>
# in_memory\basin73324
# area: 799.5680583460403
# flow length: 28.27659034729
# Average Curve Number: 79
# Average Slope: 10.026969909667969
# calculating rainfall average for
# 1 year event: 60.0456
# 2 year event: 74.549
# 5 year event: 98.2726
# 10 year event: 117.95759999999999
# 25 year event: 145.034
# 50 year event: 165.04919999999998
# 100 year event: 186.7916
# 200 year event: 213.30919999999998
# 500 year event: 253.89839999999998
# 1000 year event: 288.798
# --------------------------------
# inlet 71049
# deriving FeatureSet
# [26918]
# <geoprocessing spatial reference object object at 0x0000016FBA7212B0>
# [Point(uid=71049, lat=4690083.416399386, lng=612348.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 5, 'pointid': 5, 'grid_code': 71049, 'Survey_ID': 73678, 'NAACC_ID': 71049, 'Lat': 42.354929, 'Long': -73.635924, 'Rd_Name': 'Church Sreet', 'Culv_Mat': 'Concrete', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 3, 'In_B': 3, 'HW': 1.5, 'Slope': 3, 'Length': 40, 'Out_Shape': 'Round Culvert', 'Out_A': 3, 'Out_B': 3, 'Crossing_T': 'Culvert', 'Comments': 'buried upstream under field. fish in scour pool', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '115C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 612348.2765349206, 'y': 4690083.416399386}})]
# <geoprocessing record set object object at 0x0000016FBA721E70> {"displayFieldName":"","fieldAliases":{"OID":"OID","uid":"uid","group_id":"group_id"},"geometryType":"esriGeometryPoint","spatialReference":{"wkid":26918,"latestWkid":26918},"fields":[{"name":"OID","type":"esriFieldTypeOID","alias":"OID"},{"name":"uid","type":"esriFieldTypeString","alias":"uid"},{"name":"group_id","type":"esriFieldTypeString","alias":"group_id"}],"features":[{"attributes":{"OID":1,"uid":"71049","group_id":null},"geometry":{"x":612348.27649999969,"y":4690083.4164000005}}]}
# delineating
# in_memory\catchment_71049.tif <class 'arcpy.sa.Raster.Raster'>
# in_memory\basin71049
# area: 229475.304935253
# flow length: 1077.1088867188
# Average Curve Number: 73.64634146341463
# Average Slope: 4.215719690695664
# calculating rainfall average for
# 1 year event: 56.67912648083623
# 2 year event: 69.89079930313588
# 5 year event: 91.46438222996515
# 10 year event: 109.35403588850173
# 25 year event: 133.97999965156797
# 50 year event: 152.24901602787457
# 100 year event: 171.9700362369338
# 200 year event: 195.73032020905922
# 500 year event: 231.7626982578397
# 1000 year event: 262.51408885017423
# --------------------------------
# inlet 70962
# deriving FeatureSet
# [26918]
# <geoprocessing spatial reference object object at 0x0000016FBA721770>
# [Point(uid=70962, lat=4689973.416399388, lng=615548.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 6, 'pointid': 6, 'grid_code': 70962, 'Survey_ID': 73590, 'NAACC_ID': 70962, 'Lat': 42.353513, 'Long': -73.59691, 'Rd_Name': 'Coleman Street', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 5, 'In_B': 5, 'HW': 5.5, 'Slope': 1.3, 'Length': 65, 'Out_Shape': 'Box Culvert', 'Out_A': 5, 'Out_B': 5, 'Crossing_T': 'Culvert', 'Comments': 'considerable erosion upstream and downstream. concrete slabs laying on banks of upstream culvert visible in upstream photo', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '82C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 615548.2765349215, 'y': 4689973.416399388}})]
# <geoprocessing record set object object at 0x0000016FBA727050> {"displayFieldName":"","fieldAliases":{"OID":"OID","uid":"uid","group_id":"group_id"},"geometryType":"esriGeometryPoint","spatialReference":{"wkid":26918,"latestWkid":26918},"fields":[{"name":"OID","type":"esriFieldTypeOID","alias":"OID"},{"name":"uid","type":"esriFieldTypeString","alias":"uid"},{"name":"group_id","type":"esriFieldTypeString","alias":"group_id"}],"features":[{"attributes":{"OID":1,"uid":"70962","group_id":null},"geometry":{"x":615548.27649999969,"y":4689973.4164000005}}]}
# delineating
# in_memory\catchment_70962.tif <class 'arcpy.sa.Raster.Raster'>
# in_memory\basin70962
# area: 399.7840291730201
# flow length: 0.0
# Average Curve Number: 36
# Average Slope: 16.088239669799805
# calculating rainfall average for
# 1 year event: 57.962799999999994
# 2 year event: 71.72959999999999
# 5 year event: 94.234
# 10 year event: 112.903
# 25 year event: 138.6078
# 50 year event: 157.65779999999998
# 100 year event: 178.25719999999998
# 200 year event: 203.17459999999997
# 500 year event: 241.0968
# 1000 year event: 273.5326
# --------------------------------
# inlet 70934
# deriving FeatureSet
# [26918]
# <geoprocessing spatial reference object object at 0x0000016FBA7270F0>
# [Point(uid=70934, lat=4689953.416399388, lng=615268.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 7, 'pointid': 7, 'grid_code': 70934, 'Survey_ID': 73567, 'NAACC_ID': 70934, 'Lat': 42.353382, 'Long': -73.600233, 'Rd_Name': 'Payn Road', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 8.5, 'In_B': 1.7, 'HW': 2, 'Slope': 8.1, 'Length': 160, 'Out_Shape': 'Unknown', 'Out_A': -1, 'Out_B': -1, 'Crossing_T': 'Partially Inaccessible', 'Comments': 'looks buried under yard on outlet side. cant see far through inlet because curves to the left. possibly outlets into yard of house number 30. inlet is across the street from houses 26 and 28. Neighbor says house number 30 owner is 78 yrs old and refuses', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '67C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 615268.2765349206, 'y': 4689953.416399388}})]
# <geoprocessing record set object object at 0x0000016FBA7271B0> {"displayFieldName":"","fieldAliases":{"OID":"OID","uid":"uid","group_id":"group_id"},"geometryType":"esriGeometryPoint","spatialReference":{"wkid":26918,"latestWkid":26918},"fields":[{"name":"OID","type":"esriFieldTypeOID","alias":"OID"},{"name":"uid","type":"esriFieldTypeString","alias":"uid"},{"name":"group_id","type":"esriFieldTypeString","alias":"group_id"}],"features":[{"attributes":{"OID":1,"uid":"70934","group_id":null},"geometry":{"x":615268.27649999969,"y":4689953.4164000005}}]}
# delineating
# in_memory\catchment_70934.tif <class 'arcpy.sa.Raster.Raster'>
# in_memory\basin70934
# area: 799.562059948987
# flow length: 19.994567871094
# Average Curve Number: 41
# Average Slope: 1.820680022239685
# calculating rainfall average for
# 1 year event: 57.962799999999994
# 2 year event: 71.72959999999999
# 5 year event: 94.234
# 10 year event: 112.903
# 25 year event: 138.6078
# 50 year event: 157.65779999999998
# 100 year event: 178.25719999999998
# 200 year event: 203.17459999999997
# 500 year event: 241.0968
# 1000 year event: 273.5326
# --------------------------------
# inlet 70964
# deriving FeatureSet
# [26918]
# <geoprocessing spatial reference object object at 0x0000016FBA727310>
# [Point(uid=70964, lat=4689873.416399386, lng=615198.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 8, 'pointid': 8, 'grid_code': 70964, 'Survey_ID': 73592, 'NAACC_ID': 70964, 'Lat': 42.352664, 'Long': -73.601273, 'Rd_Name': 'Elm Street', 'Culv_Mat': 'Concrete', 'In_Type': 'Wingwall and Headwall', 'In_Shape': 'Box', 'In_A': 8, 'In_B': 3.2, 'HW': 2.2, 'Slope': 1.9, 'Length': 40, 'Out_Shape': 'Box Culvert', 'Out_A': 8, 'Out_B': 5, 'Crossing_T': 'Culvert', 'Comments': 'small fish and frogs in stream. neighbor says blue heron uses stream. drain grate in between structure and Payn St floods road, sidewalk and yard of house 5. Flooding happens when structure on Payne st floods', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '84C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 615198.2765349215, 'y': 4689873.416399386}})]
# <geoprocessing record set object object at 0x0000016FBA7273B0> {"displayFieldName":"","fieldAliases":{"OID":"OID","uid":"uid","group_id":"group_id"},"geometryType":"esriGeometryPoint","spatialReference":{"wkid":26918,"latestWkid":26918},"fields":[{"name":"OID","type":"esriFieldTypeOID","alias":"OID"},{"name":"uid","type":"esriFieldTypeString","alias":"uid"},{"name":"group_id","type":"esriFieldTypeString","alias":"group_id"}],"features":[{"attributes":{"OID":1,"uid":"70964","group_id":null},"geometry":{"x":615198.27649999969,"y":4689873.4164000005}}]}
# delineating
# in_memory\catchment_70964.tif <class 'arcpy.sa.Raster.Raster'>
# in_memory\basin70964
# area: 41977.19309716403
# flow length: 562.68981933594
# Average Curve Number: 41.923809523809524
# Average Slope: 8.181410719667163
# calculating rainfall average for
# 1 year event: 57.98118476190476
# 2 year event: 71.7547580952381
# 5 year event: 94.2698019047619
# 10 year event: 112.94654285714283
# 25 year event: 138.66295428571428
# 50 year event: 157.72069523809523
# 100 year event: 178.32977142857143
# 200 year event: 203.25975047619048
# 500 year event: 241.2032380952381
# 1000 year event: 273.6583904761905
# --------------------------------
# inlet 72494
# deriving FeatureSet
# [26918]
# <geoprocessing spatial reference object object at 0x0000016FBA7274F0>
# [Point(uid=72494, lat=4689843.416399386, lng=614758.2765349215, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 9, 'pointid': 9, 'grid_code': 72494, 'Survey_ID': 75154, 'NAACC_ID': 72494, 'Lat': 42.352439, 'Long': -73.606888, 'Rd_Name': 'Hudson Plaza', 'Culv_Mat': 'Concrete', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 2, 'In_B': 1.7, 'HW': 1, 'Slope': 8.1, 'Length': 100, 'Out_Shape': 'Round Culvert', 'Out_A': 2, 'Out_B': 1.5, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '197C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 614758.2765349215, 'y': 4689843.416399386}})]
# <geoprocessing record set object object at 0x0000016FBA727250> {"displayFieldName":"","fieldAliases":{"OID":"OID","uid":"uid","group_id":"group_id"},"geometryType":"esriGeometryPoint","spatialReference":{"wkid":26918,"latestWkid":26918},"fields":[{"name":"OID","type":"esriFieldTypeOID","alias":"OID"},{"name":"uid","type":"esriFieldTypeString","alias":"uid"},{"name":"group_id","type":"esriFieldTypeString","alias":"group_id"}],"features":[{"attributes":{"OID":1,"uid":"72494","group_id":null},"geometry":{"x":614758.27649999969,"y":4689843.4164000005}}]}
# delineating
# in_memory\catchment_72494.tif <class 'arcpy.sa.Raster.Raster'>
# in_memory\basin72494
# area: 34781.104565461676
# flow length: 281.34494018555
# Average Curve Number: 58.35632183908046
# Average Slope: 1.5085030776159516
# calculating rainfall average for
# 1 year event: 57.658
# 2 year event: 71.29780000000001
# 5 year event: 93.599
# 10 year event: 112.141
# 25 year event: 137.61719999999997
# 50 year event: 156.4894
# 100 year event: 176.911
# 200 year event: 201.5744
# 500 year event: 239.0648
# 1000 year event: 271.1196
# --------------------------------
# inlet 70995
# deriving FeatureSet
# [26918]
# <geoprocessing spatial reference object object at 0x0000016FBA727590>
# [Point(uid=70995, lat=4689743.416399388, lng=620528.2765349206, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=None, analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 10, 'pointid': 10, 'grid_code': 70995, 'Survey_ID': 73624, 'NAACC_ID': 70995, 'Lat': 42.350532, 'Long': -73.53654, 'Rd_Name': 'Ten Broek Road', 'Culv_Mat': 'Plastic', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 4, 'In_B': 3.8, 'HW': 2.8, 'Slope': 9.1, 'Length': 40, 'Out_Shape': 'Round Culvert', 'Out_A': 3.9, 'Out_B': 3.8, 'Crossing_T': 'Culvert', 'Comments': 'driveway culvert upstream. lots of erosion downstream', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '107C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 620528.2765349206, 'y': 4689743.416399388}})]
# <geoprocessing record set object object at 0x0000016FBA7277B0> {"displayFieldName":"","fieldAliases":{"OID":"OID","uid":"uid","group_id":"group_id"},"geometryType":"esriGeometryPoint","spatialReference":{"wkid":26918,"latestWkid":26918},"fields":[{"name":"OID","type":"esriFieldTypeOID","alias":"OID"},{"name":"uid","type":"esriFieldTypeString","alias":"uid"},{"name":"group_id","type":"esriFieldTypeString","alias":"group_id"}],"features":[{"attributes":{"OID":1,"uid":"70995","group_id":null},"geometry":{"x":620528.27649999969,"y":4689743.4164000005}}]}
# delineating
# in_memory\catchment_70995.tif <class 'arcpy.sa.Raster.Raster'>
# in_memory\basin70995
# area: 321425.3297240745
# flow length: 1317.0439453125
# Average Curve Number: 78.13930348258707
# Average Slope: 12.584468117400782
# calculating rainfall average for
# 1 year event: 61.21447388059701
# 2 year event: 76.19459776119402
# 5 year event: 100.67119402985074
# 10 year event: 120.98323283582089
# 25 year event: 148.92579179104476
# 50 year event: 169.5551410447761
# 100 year event: 192.02513731343282
# 200 year event: 219.61342313432834
# 500 year event: 262.13198059701494
# 1000 year event: 298.79934477611937

# %%
print(points[0])
# Out:
# Point(uid=70978, lat=4690423.416399388, lng=618918.2765349224, spatial_ref_code=26918, group_id=None, naacc=None, capacity=None, shed=Shed(uid=70978, group_id=None, area_sqkm=3198.260236505569, avg_slope_pct=16.102196872234344, avg_cn=77.75, max_fl=88.260292053223, rainfall=[Rainfall(freq=1, dur='24hr', value=59.74079999999999), Rainfall(freq=2, dur='24hr', value=74.1172), Rainfall(freq=5, dur='24hr', value=97.6122), Rainfall(freq=10, dur='24hr', value=117.1194), Rainfall(freq=25, dur='24hr', value=143.9672), Rainfall(freq=50, dur='24hr', value=163.80459999999997), Rainfall(freq=100, dur='24hr', value=185.3438), Rainfall(freq=200, dur='24hr', value=211.63279999999997), Rainfall(freq=500, dur='24hr', value=251.94259999999997), Rainfall(freq=1000, dur='24hr', value=286.61359999999996)], inlet_geom=None, shed_geom=None, shed_polygon_filepath='in_memory\\basin70978_dissolved', shed_raster_filepath='in_memory/catchment_70978.tif'), analytics=[], include=True, validation_errors={}, notes=[], raw={'OBJECTID': 1, 'pointid': 1, 'grid_code': 70978, 'Survey_ID': 73607, 'NAACC_ID': 70978, 'Lat': 42.35717, 'Long': -73.556041, 'Rd_Name': 'Raup Road', 'Culv_Mat': 'Metal', 'In_Type': 'Projecting', 'In_Shape': 'Round', 'In_A': 4.9, 'In_B': 4.8, 'HW': 2, 'Slope': 2.8, 'Length': 26, 'Out_Shape': 'Round Culvert', 'Out_A': 5.2, 'Out_B': 5.4, 'Crossing_T': 'Culvert', 'Comments': ' ', 'Flags': 1, 'Modeling_n': ' ', 'BarrierID': '96C19', 'BarrierID_': 0, 'BarrierID1': 0, 'geometry': {'x': 618918.2765349224, 'y': 4690423.416399388}})

# %%
PointSchema = class_schema(Point)

# %%
test_point = PointSchema().dump(points[0])

# %%
pp(test_point)
# Out:
# { 'analytics': [],
#   'capacity': None,
#   'group_id': None,
#   'include': True,
#   'lat': 4690423.416399388,
#   'lng': 618918.2765349224,
#   'naacc': None,
#   'notes': [],
#   'raw': { 'BarrierID': '96C19',
#            'BarrierID1': 0,
#            'BarrierID_': 0,
#            'Comments': ' ',
#            'Crossing_T': 'Culvert',
#            'Culv_Mat': 'Metal',
#            'Flags': 1,
#            'HW': 2,
#            'In_A': 4.9,
#            'In_B': 4.8,
#            'In_Shape': 'Round',
#            'In_Type': 'Projecting',
#            'Lat': 42.35717,
#            'Length': 26,
#            'Long': -73.556041,
#            'Modeling_n': ' ',
#            'NAACC_ID': 70978,
#            'OBJECTID': 1,
#            'Out_A': 5.2,
#            'Out_B': 5.4,
#            'Out_Shape': 'Round Culvert',
#            'Rd_Name': 'Raup Road',
#            'Slope': 2.8,
#            'Survey_ID': 73607,
#            'geometry': {'x': 618918.2765349224, 'y': 4690423.416399388},
#            'grid_code': 70978,
#            'pointid': 1},
#   'shed': { 'area_sqkm': 3198.260236505569,
#             'avg_cn': 77.75,
#             'avg_slope_pct': 16.102196872234344,
#             'group_id': None,
#             'inlet_geom': None,
#             'max_fl': 88.260292053223,
#             'rainfall': [ { 'dur': '24hr',
#                             'freq': 1,
#                             'value': 59.74079999999999},
#                           {'dur': '24hr', 'freq': 2, 'value': 74.1172},
#                           {'dur': '24hr', 'freq': 5, 'value': 97.6122},
#                           {'dur': '24hr', 'freq': 10, 'value': 117.1194},
#                           {'dur': '24hr', 'freq': 25, 'value': 143.9672},
#                           { 'dur': '24hr',
#                             'freq': 50,
#                             'value': 163.80459999999997},
#                           {'dur': '24hr', 'freq': 100, 'value': 185.3438},
#                           { 'dur': '24hr',
#                             'freq': 200,
#                             'value': 211.63279999999997},
#                           { 'dur': '24hr',
#                             'freq': 500,
#                             'value': 251.94259999999997},
#                           { 'dur': '24hr',
#                             'freq': 1000,
#                             'value': 286.61359999999996}],
#             'shed_geom': None,
#             'shed_polygon_filepath': 'in_memory\\basin70978_dissolved',
#             'shed_raster_filepath': 'in_memory/catchment_70978.tif',
#             'uid': '70978'},
#   'spatial_ref_code': 26918,
#   'uid': '70978',
#   'validation_errors': {}}

# %%
json.dumps(test_point)
# Out:
# '{"shed": {"area_sqkm": 3198.260236505569, "avg_slope_pct": 16.102196872234344, "rainfall": [{"freq": 1, "value": 59.74079999999999, "dur": "24hr"}, {"freq": 2, "value": 74.1172, "dur": "24hr"}, {"freq": 5, "value": 97.6122, "dur": "24hr"}, {"freq": 10, "value": 117.1194, "dur": "24hr"}, {"freq": 25, "value": 143.9672, "dur": "24hr"}, {"freq": 50, "value": 163.80459999999997, "dur": "24hr"}, {"freq": 100, "value": 185.3438, "dur": "24hr"}, {"freq": 200, "value": 211.63279999999997, "dur": "24hr"}, {"freq": 500, "value": 251.94259999999997, "dur": "24hr"}, {"freq": 1000, "value": 286.61359999999996, "dur": "24hr"}], "shed_raster_filepath": "in_memory/catchment_70978.tif", "avg_cn": 77.75, "max_fl": 88.260292053223, "uid": "70978", "shed_geom": null, "shed_polygon_filepath": "in_memory\\\\basin70978_dissolved", "inlet_geom": null, "group_id": null}, "analytics": [], "capacity": null, "spatial_ref_code": 26918, "lng": 618918.2765349224, "include": true, "validation_errors": {}, "notes": [], "uid": "70978", "naacc": null, "lat": 4690423.416399388, "raw": {"OBJECTID": 1, "pointid": 1, "grid_code": 70978, "Survey_ID": 73607, "NAACC_ID": 70978, "Lat": 42.35717, "Long": -73.556041, "Rd_Name": "Raup Road", "Culv_Mat": "Metal", "In_Type": "Projecting", "In_Shape": "Round", "In_A": 4.9, "In_B": 4.8, "HW": 2, "Slope": 2.8, "Length": 26, "Out_Shape": "Round Culvert", "Out_A": 5.2, "Out_B": 5.4, "Crossing_T": "Culvert", "Comments": " ", "Flags": 1, "Modeling_n": " ", "BarrierID": "96C19", "BarrierID_": 0, "BarrierID1": 0, "geometry": {"x": 618918.2765349224, "y": 4690423.416399388}}, "group_id": null}'

# %%
all_points_dicts = []
for p in points:
    all_points_dicts.append(PointSchema().dump(p))

# %%
with open(r"C:\Users\chris\dev\drainage\drainit\tests\point_after_delin.json", 'w') as fp:
    json.dump({"points": all_points_dicts}, fp)
